# %% [markdown]
# # Fine-tuning LoRA: Slides description

# %% [markdown]
# ## 1  Instalación de dependencias

# %%
! pip install backoff transformers==4.49 peft
! pip install sacrebleu unbabel-comet
# Out:
# Requirement already satisfied: backoff in /usr/local/lib/python3.12/dist-packages (2.2.1)
# Requirement already satisfied: transformers==4.49 in /usr/local/lib/python3.12/dist-packages (4.49.0)
# Requirement already satisfied: peft in /usr/local/lib/python3.12/dist-packages (0.17.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers==4.49) (3.19.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.26.0 in /usr/local/lib/python3.12/dist-packages (from transformers==4.49) (0.34.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers==4.49) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers==4.49) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers==4.49) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers==4.49) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers==4.49) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.12/dist-packages (from transformers==4.49) (0.21.4)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from transformers==4.49) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers==4.49) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from peft) (5.9.5)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.12/dist-packages (from peft) (2.8.0+cu126)
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from peft) (1.10.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.26.0->transformers==4.49) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.26.0->transformers==4.49) (4.14.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.26.0->transformers==4.49) (1.1.7)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (3.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.49) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.49) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.49) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.49) (2025.8.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.13.0->peft) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.13.0->peft) (3.0.2)
# Requirement already satisfied: sacrebleu in /usr/local/lib/python3.12/dist-packages (2.5.1)
# Requirement already satisfied: unbabel-comet in /usr/local/lib/python3.12/dist-packages (2.2.6)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.12/dist-packages (from sacrebleu) (3.2.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from sacrebleu) (2024.11.6)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.12/dist-packages (from sacrebleu) (0.9.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from sacrebleu) (1.26.4)
# Requirement already satisfied: colorama in /usr/local/lib/python3.12/dist-packages (from sacrebleu) (0.4.6)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (from sacrebleu) (5.4.0)
# Requirement already satisfied: entmax<2.0,>=1.1 in /usr/local/lib/python3.12/dist-packages (from unbabel-comet) (1.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.12/dist-packages (from unbabel-comet) (0.34.4)
# Requirement already satisfied: jsonargparse==3.13.1 in /usr/local/lib/python3.12/dist-packages (from unbabel-comet) (3.13.1)
# Requirement already satisfied: pandas>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from unbabel-comet) (2.2.2)
# Requirement already satisfied: protobuf<5.0.0,>=4.24.4 in /usr/local/lib/python3.12/dist-packages (from unbabel-comet) (4.25.8)
# Requirement already satisfied: pytorch-lightning<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from unbabel-comet) (2.5.3)
# Requirement already satisfied: scipy<2.0.0,>=1.5.4 in /usr/local/lib/python3.12/dist-packages (from unbabel-comet) (1.16.1)
# Requirement already satisfied: sentencepiece<0.3.0,>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from unbabel-comet) (0.2.1)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from unbabel-comet) (2.8.0+cu126)
# Requirement already satisfied: torchmetrics<0.11.0,>=0.10.2 in /usr/local/lib/python3.12/dist-packages (from unbabel-comet) (0.10.3)
# Requirement already satisfied: transformers<5.0,>=4.17 in /usr/local/lib/python3.12/dist-packages (from unbabel-comet) (4.49.0)
# Requirement already satisfied: PyYAML>=3.13 in /usr/local/lib/python3.12/dist-packages (from jsonargparse==3.13.1->unbabel-comet) (6.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.19.3->unbabel-comet) (3.19.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.19.3->unbabel-comet) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.19.3->unbabel-comet) (25.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.19.3->unbabel-comet) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.19.3->unbabel-comet) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.19.3->unbabel-comet) (4.14.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.19.3->unbabel-comet) (1.1.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.4.1->unbabel-comet) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.4.1->unbabel-comet) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.4.1->unbabel-comet) (2025.2)
# Requirement already satisfied: lightning-utilities>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from pytorch-lightning<3.0.0,>=2.0.0->unbabel-comet) (0.15.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->unbabel-comet) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->unbabel-comet) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->unbabel-comet) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->unbabel-comet) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->unbabel-comet) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->unbabel-comet) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->unbabel-comet) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->unbabel-comet) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->unbabel-comet) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->unbabel-comet) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->unbabel-comet) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->unbabel-comet) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->unbabel-comet) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->unbabel-comet) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->unbabel-comet) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->unbabel-comet) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->unbabel-comet) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->unbabel-comet) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.6.0->unbabel-comet) (3.4.0)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0,>=4.17->unbabel-comet) (0.21.4)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0,>=4.17->unbabel-comet) (0.6.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2022.5.0->pytorch-lightning<3.0.0,>=2.0.0->unbabel-comet) (3.12.15)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.4.1->unbabel-comet) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.6.0->unbabel-comet) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.6.0->unbabel-comet) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub<1.0,>=0.19.3->unbabel-comet) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub<1.0,>=0.19.3->unbabel-comet) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub<1.0,>=0.19.3->unbabel-comet) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub<1.0,>=0.19.3->unbabel-comet) (2025.8.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning<3.0.0,>=2.0.0->unbabel-comet) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning<3.0.0,>=2.0.0->unbabel-comet) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning<3.0.0,>=2.0.0->unbabel-comet) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning<3.0.0,>=2.0.0->unbabel-comet) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning<3.0.0,>=2.0.0->unbabel-comet) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning<3.0.0,>=2.0.0->unbabel-comet) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning<3.0.0,>=2.0.0->unbabel-comet) (1.20.1)

# %%
from google.colab import drive
import os

# Montar Google Drive
drive.mount('/content/drive')

# Rutas de los archivos zip en Google Drive
test_zip_path = '/content/drive/MyDrive/test.zip'
dev_zip_path = '/content/drive/MyDrive/dev.zip'
test_lst = '/content/drive/MyDrive/test.lst'
dev_lst = '/content/drive/MyDrive/dev.lst'

# Directorio de destino en Colab
colab_content_path = '/content/'

# Copiar los archivos zip a Colab
# !cp "{test_zip_path}" "{colab_content_path}"
# !cp "{dev_zip_path}" "{colab_content_path}"
# !cp "{test_lst}" "{colab_content_path}"
# !cp "{dev_lst}" "{colab_content_path}"

print(f"Archivos copiados a {colab_content_path}")
print(os.listdir(colab_content_path))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Archivos copiados a /content/
# ['.config', 'dev.zip', 'test.lst', 'drive', 'dev.lst', 'test.zip', 'sample_data']

# %%
# !unzip /content/test.zip -d /content/test
# !unzip /content/dev.zip -d /content/dev
# Out:
# Archive:  /content/test.zip
#    creating: /content/test/404/
#    creating: /content/test/545006/
#    creating: /content/test/596001/
#    creating: /content/test/605000/
#    creating: /content/test/606/
#   inflating: /content/test/test.lst
#    creating: /content/test/606/manual_transcription/
#    creating: /content/test/606/manual_translations/
#   inflating: /content/test/606/slides.pptx
#   inflating: /content/test/606/606.m4a
#    creating: /content/test/606/manual_transcription/sentence_segmented/
#   inflating: /content/test/606/manual_transcription/ie606.srt
#   inflating: /content/test/606/manual_transcription/ie606.txt
#   inflating: /content/test/606/manual_transcription/sentence_segmented/ie606.srt
#    creating: /content/test/606/manual_translations/de/
#    creating: /content/test/606/manual_translations/es/
#    creating: /content/test/606/manual_translations/fr/
#    creating: /content/test/606/manual_translations/sl/
#   inflating: /content/test/606/manual_translations/fr/606.lst
#   inflating: /content/test/606/manual_translations/fr/606.en
#   inflating: /content/test/606/manual_translations/fr/606.fr
#   inflating: /content/test/606/manual_translations/fr/606.docx
#   inflating: /content/test/606/manual_translations/sl/606.lst
#   inflating: /content/test/606/manual_translations/sl/606.en
#   inflating: /content/test/606/manual_translations/sl/606.sl
#   inflating: /content/test/606/manual_translations/sl/606.docx
#   inflating: /content/test/606/manual_translations/es/606.lst
#   inflating: /content/test/606/manual_translations/es/606.en
#   inflating: /content/test/606/manual_translations/es/606.docx
#   inflating: /content/test/606/manual_translations/es/606.es
#   inflating: /content/test/606/manual_translations/de/606.lst
#   inflating: /content/test/606/manual_translations/de/606.en
#   inflating: /content/test/606/manual_translations/de/606.docx
#   inflating: /content/test/606/manual_translations/de/606.de
#    creating: /content/test/404/manual_transcription/
#    creating: /content/test/404/manual_translations/
#   inflating: /content/test/404/404.m4a
#   inflating: /content/test/404/slides.pptx
#    creating: /content/test/404/manual_transcription/sentence_segmented/
#   inflating: /content/test/404/manual_transcription/ie404.txt
#   inflating: /content/test/404/manual_transcription/ie404.srt
#   inflating: /content/test/404/manual_transcription/sentence_segmented/ie404.srt
#    creating: /content/test/404/manual_translations/de/
#    creating: /content/test/404/manual_translations/es/
#    creating: /content/test/404/manual_translations/fr/
#    creating: /content/test/404/manual_translations/sl/
#   inflating: /content/test/404/manual_translations/fr/404.docx
#   inflating: /content/test/404/manual_translations/fr/404.en
#   inflating: /content/test/404/manual_translations/fr/404.lst
#   inflating: /content/test/404/manual_translations/fr/404.fr
#   inflating: /content/test/404/manual_translations/sl/404.docx
#   inflating: /content/test/404/manual_translations/sl/404.sl
#   inflating: /content/test/404/manual_translations/sl/404.en
#   inflating: /content/test/404/manual_translations/sl/404.lst
#   inflating: /content/test/404/manual_translations/es/404.es
#   inflating: /content/test/404/manual_translations/es/404.docx
#   inflating: /content/test/404/manual_translations/es/404.en
#   inflating: /content/test/404/manual_translations/es/404.lst
#   inflating: /content/test/404/manual_translations/de/404.docx
#   inflating: /content/test/404/manual_translations/de/404.de
#   inflating: /content/test/404/manual_translations/de/404.en
#   inflating: /content/test/404/manual_translations/de/404.lst
#    creating: /content/test/596001/manual_transcription/
#    creating: /content/test/596001/manual_translations/
#   inflating: /content/test/596001/596001.m4a
#   inflating: /content/test/596001/slides.pptx
#    creating: /content/test/596001/manual_transcription/sentence_segmented/
#   inflating: /content/test/596001/manual_transcription/ie596001.srt
#   inflating: /content/test/596001/manual_transcription/ie596001.txt
#   inflating: /content/test/596001/manual_transcription/sentence_segmented/ie596001.srt
#    creating: /content/test/596001/manual_translations/de/
#    creating: /content/test/596001/manual_translations/es/
#    creating: /content/test/596001/manual_translations/fr/
#    creating: /content/test/596001/manual_translations/sl/
#   inflating: /content/test/596001/manual_translations/fr/596001.en
#   inflating: /content/test/596001/manual_translations/fr/596001.fr
#   inflating: /content/test/596001/manual_translations/fr/596001.lst
#   inflating: /content/test/596001/manual_translations/fr/596001.docx
#   inflating: /content/test/596001/manual_translations/sl/596001.en
#   inflating: /content/test/596001/manual_translations/sl/596001.lst
#   inflating: /content/test/596001/manual_translations/sl/596001.sl
#   inflating: /content/test/596001/manual_translations/sl/596001.docx
#   inflating: /content/test/596001/manual_translations/es/596001.es
#   inflating: /content/test/596001/manual_translations/es/596001.en
#   inflating: /content/test/596001/manual_translations/es/596001.lst
#   inflating: /content/test/596001/manual_translations/es/596001.docx
#   inflating: /content/test/596001/manual_translations/de/596001.de
#   inflating: /content/test/596001/manual_translations/de/596001.en
#   inflating: /content/test/596001/manual_translations/de/596001.lst
#   inflating: /content/test/596001/manual_translations/de/596001.docx
#    creating: /content/test/605000/manual_transcription/
#    creating: /content/test/605000/manual_translations/
#   inflating: /content/test/605000/605000.m4a
#   inflating: /content/test/605000/slides.pptx
#    creating: /content/test/605000/manual_transcription/sentence_segmented/
#   inflating: /content/test/605000/manual_transcription/ie605000.txt
#   inflating: /content/test/605000/manual_transcription/ie605000.srt
#   inflating: /content/test/605000/manual_transcription/sentence_segmented/ie605000.srt
#    creating: /content/test/605000/manual_translations/de/
#    creating: /content/test/605000/manual_translations/es/
#    creating: /content/test/605000/manual_translations/fr/
#    creating: /content/test/605000/manual_translations/sl/
#   inflating: /content/test/605000/manual_translations/fr/605000.en
#   inflating: /content/test/605000/manual_translations/fr/605000.lst
#   inflating: /content/test/605000/manual_translations/fr/605000.fr
#   inflating: /content/test/605000/manual_translations/fr/605000.docx
#   inflating: /content/test/605000/manual_translations/sl/605000.en
#   inflating: /content/test/605000/manual_translations/sl/605000.lst
#   inflating: /content/test/605000/manual_translations/sl/605000.sl
#   inflating: /content/test/605000/manual_translations/sl/605000.docx
#   inflating: /content/test/605000/manual_translations/es/605000.en
#   inflating: /content/test/605000/manual_translations/es/605000.es
#   inflating: /content/test/605000/manual_translations/es/605000.lst
#   inflating: /content/test/605000/manual_translations/es/605000.docx
#   inflating: /content/test/605000/manual_translations/de/605000.en
#   inflating: /content/test/605000/manual_translations/de/605000.de
#   inflating: /content/test/605000/manual_translations/de/605000.lst
#   inflating: /content/test/605000/manual_translations/de/605000.docx
#    creating: /content/test/545006/manual_transcription/
#    creating: /content/test/545006/manual_translations/
#   inflating: /content/test/545006/slides.pdf
#   inflating: /content/test/545006/545006.m4a
#    creating: /content/test/545006/manual_transcription/sentence_segmented/
#   inflating: /content/test/545006/manual_transcription/ie545006.txt
#   inflating: /content/test/545006/manual_transcription/ie545006.srt
#   inflating: /content/test/545006/manual_transcription/sentence_segmented/ie545006.srt
#    creating: /content/test/545006/manual_translations/de/
#    creating: /content/test/545006/manual_translations/es/
#    creating: /content/test/545006/manual_translations/fr/
#    creating: /content/test/545006/manual_translations/sl/
#   inflating: /content/test/545006/manual_translations/fr/545006.fr
#   inflating: /content/test/545006/manual_translations/fr/545006.docx
#   inflating: /content/test/545006/manual_translations/fr/545006.en
#   inflating: /content/test/545006/manual_translations/fr/545006.lst
#   inflating: /content/test/545006/manual_translations/sl/545006.docx
#   inflating: /content/test/545006/manual_translations/sl/545006.en
#   inflating: /content/test/545006/manual_translations/sl/545006.sl
#   inflating: /content/test/545006/manual_translations/sl/545006.lst
#   inflating: /content/test/545006/manual_translations/es/545006.docx
#   inflating: /content/test/545006/manual_translations/es/545006.en
#   inflating: /content/test/545006/manual_translations/es/545006.es
#   inflating: /content/test/545006/manual_translations/es/545006.lst
#   inflating: /content/test/545006/manual_translations/de/545006.de
#   inflating: /content/test/545006/manual_translations/de/545006.docx
#   inflating: /content/test/545006/manual_translations/de/545006.en
#   inflating: /content/test/545006/manual_translations/de/545006.lst
# Archive:  /content/dev.zip
#    creating: /content/dev/500011/
#    creating: /content/dev/550000/
#    creating: /content/dev/592/
#    creating: /content/dev/609/
#    creating: /content/dev/624000/
#   inflating: /content/dev/dev.lst
#    creating: /content/dev/609/manual_transcription/
#    creating: /content/dev/609/manual_translations/
#   inflating: /content/dev/609/slides.pptx
#   inflating: /content/dev/609/609.m4a
#    creating: /content/dev/609/manual_transcription/sentence_segmented/
#   inflating: /content/dev/609/manual_transcription/ie609.srt
#   inflating: /content/dev/609/manual_transcription/ie609.txt
#   inflating: /content/dev/609/manual_transcription/sentence_segmented/ie609.srt
#    creating: /content/dev/609/manual_translations/de/
#    creating: /content/dev/609/manual_translations/es/
#    creating: /content/dev/609/manual_translations/fr/
#    creating: /content/dev/609/manual_translations/sl/
#   inflating: /content/dev/609/manual_translations/fr/609.lst
#   inflating: /content/dev/609/manual_translations/fr/609.docx
#   inflating: /content/dev/609/manual_translations/fr/609.fr
#   inflating: /content/dev/609/manual_translations/fr/609.en
#   inflating: /content/dev/609/manual_translations/sl/609.lst
#   inflating: /content/dev/609/manual_translations/sl/609.docx
#   inflating: /content/dev/609/manual_translations/sl/609.sl
#   inflating: /content/dev/609/manual_translations/sl/609.en
#   inflating: /content/dev/609/manual_translations/es/609.lst
#   inflating: /content/dev/609/manual_translations/es/609.docx
#   inflating: /content/dev/609/manual_translations/es/609.es
#   inflating: /content/dev/609/manual_translations/es/609.en
#   inflating: /content/dev/609/manual_translations/de/609.lst
#   inflating: /content/dev/609/manual_translations/de/609.docx
#   inflating: /content/dev/609/manual_translations/de/609.de
#   inflating: /content/dev/609/manual_translations/de/609.en
#    creating: /content/dev/592/manual_transcription/
#    creating: /content/dev/592/manual_translations/
#   inflating: /content/dev/592/slides.ppt
#   inflating: /content/dev/592/592.m4a
#    creating: /content/dev/592/manual_transcription/sentence_segmented/
#   inflating: /content/dev/592/manual_transcription/ie592.srt
#   inflating: /content/dev/592/manual_transcription/ie592.txt
#   inflating: /content/dev/592/manual_transcription/sentence_segmented/ie592.srt
#    creating: /content/dev/592/manual_translations/de/
#    creating: /content/dev/592/manual_translations/es/
#    creating: /content/dev/592/manual_translations/fr/
#    creating: /content/dev/592/manual_translations/sl/
#   inflating: /content/dev/592/manual_translations/fr/592.en
#   inflating: /content/dev/592/manual_translations/fr/592.fr
#   inflating: /content/dev/592/manual_translations/fr/592.lst
#   inflating: /content/dev/592/manual_translations/fr/592.docx
#   inflating: /content/dev/592/manual_translations/sl/592.en
#   inflating: /content/dev/592/manual_translations/sl/592.lst
#   inflating: /content/dev/592/manual_translations/sl/592.sl
#   inflating: /content/dev/592/manual_translations/sl/592.docx
#   inflating: /content/dev/592/manual_translations/es/592.en
#   inflating: /content/dev/592/manual_translations/es/592.es
#   inflating: /content/dev/592/manual_translations/es/592.lst
#   inflating: /content/dev/592/manual_translations/es/592.docx
#   inflating: /content/dev/592/manual_translations/de/592.de
#   inflating: /content/dev/592/manual_translations/de/592.en
#   inflating: /content/dev/592/manual_translations/de/592.lst
#   inflating: /content/dev/592/manual_translations/de/592.docx
#    creating: /content/dev/624000/manual_transcription/
#    creating: /content/dev/624000/manual_translations/
#   inflating: /content/dev/624000/slides.pptx
#   inflating: /content/dev/624000/624000.m4a
#    creating: /content/dev/624000/manual_transcription/sentence_segmented/
#   inflating: /content/dev/624000/manual_transcription/ie624000.srt
#   inflating: /content/dev/624000/manual_transcription/ie624000.txt
#   inflating: /content/dev/624000/manual_transcription/sentence_segmented/ie624000.srt
#    creating: /content/dev/624000/manual_translations/de/
#    creating: /content/dev/624000/manual_translations/es/
#    creating: /content/dev/624000/manual_translations/fr/
#    creating: /content/dev/624000/manual_translations/sl/
#   inflating: /content/dev/624000/manual_translations/fr/624000.docx
#   inflating: /content/dev/624000/manual_translations/fr/624000.lst
#   inflating: /content/dev/624000/manual_translations/fr/624000.en
#   inflating: /content/dev/624000/manual_translations/fr/624000.fr
#   inflating: /content/dev/624000/manual_translations/sl/624000.docx
#   inflating: /content/dev/624000/manual_translations/sl/624000.lst
#   inflating: /content/dev/624000/manual_translations/sl/624000.en
#   inflating: /content/dev/624000/manual_translations/sl/624000.sl
#   inflating: /content/dev/624000/manual_translations/es/624000.docx
#   inflating: /content/dev/624000/manual_translations/es/624000.lst
#   inflating: /content/dev/624000/manual_translations/es/624000.es
#   inflating: /content/dev/624000/manual_translations/es/624000.en
#   inflating: /content/dev/624000/manual_translations/de/624000.docx
#   inflating: /content/dev/624000/manual_translations/de/624000.lst
#   inflating: /content/dev/624000/manual_translations/de/624000.de
#   inflating: /content/dev/624000/manual_translations/de/624000.en
#    creating: /content/dev/500011/manual_transcription/
#    creating: /content/dev/500011/manual_translations/
#   inflating: /content/dev/500011/500011.m4a
#   inflating: /content/dev/500011/slides.pdf
#    creating: /content/dev/500011/manual_transcription/sentence_segmented/
#   inflating: /content/dev/500011/manual_transcription/ie500011.txt
#   inflating: /content/dev/500011/manual_transcription/ie500011.srt
#   inflating: /content/dev/500011/manual_transcription/sentence_segmented/ie500011.srt
#    creating: /content/dev/500011/manual_translations/de/
#    creating: /content/dev/500011/manual_translations/es/
#    creating: /content/dev/500011/manual_translations/fr/
#    creating: /content/dev/500011/manual_translations/sl/
#   inflating: /content/dev/500011/manual_translations/fr/500011.fr
#   inflating: /content/dev/500011/manual_translations/fr/500011.lst
#   inflating: /content/dev/500011/manual_translations/fr/500011.docx
#   inflating: /content/dev/500011/manual_translations/fr/500011.en
#   inflating: /content/dev/500011/manual_translations/sl/500011.lst
#   inflating: /content/dev/500011/manual_translations/sl/500011.docx
#   inflating: /content/dev/500011/manual_translations/sl/500011.en
#   inflating: /content/dev/500011/manual_translations/sl/500011.sl
#   inflating: /content/dev/500011/manual_translations/es/500011.lst
#   inflating: /content/dev/500011/manual_translations/es/500011.docx
#   inflating: /content/dev/500011/manual_translations/es/500011.en
#   inflating: /content/dev/500011/manual_translations/es/500011.es
#   inflating: /content/dev/500011/manual_translations/de/500011.lst
#   inflating: /content/dev/500011/manual_translations/de/500011.de
#   inflating: /content/dev/500011/manual_translations/de/500011.docx
#   inflating: /content/dev/500011/manual_translations/de/500011.en
#    creating: /content/dev/550000/manual_transcription/
#    creating: /content/dev/550000/manual_translations/
#   inflating: /content/dev/550000/slides.pptx
#   inflating: /content/dev/550000/550000.m4a
#    creating: /content/dev/550000/manual_transcription/sentence_segmented/
#   inflating: /content/dev/550000/manual_transcription/ie550000.srt
#   inflating: /content/dev/550000/manual_transcription/ie550000.txt
#   inflating: /content/dev/550000/manual_transcription/sentence_segmented/ie550000.srt
#    creating: /content/dev/550000/manual_translations/de/
#    creating: /content/dev/550000/manual_translations/es/
#    creating: /content/dev/550000/manual_translations/fr/
#    creating: /content/dev/550000/manual_translations/sl/
#   inflating: /content/dev/550000/manual_translations/fr/550000.fr
#   inflating: /content/dev/550000/manual_translations/fr/550000.docx
#   inflating: /content/dev/550000/manual_translations/fr/550000.en
#   inflating: /content/dev/550000/manual_translations/fr/550000.lst
#   inflating: /content/dev/550000/manual_translations/sl/550000.sl
#   inflating: /content/dev/550000/manual_translations/sl/550000.docx
#   inflating: /content/dev/550000/manual_translations/sl/550000.en
#   inflating: /content/dev/550000/manual_translations/sl/550000.lst
#   inflating: /content/dev/550000/manual_translations/es/550000.docx
#   inflating: /content/dev/550000/manual_translations/es/550000.en
#   inflating: /content/dev/550000/manual_translations/es/550000.lst
#   inflating: /content/dev/550000/manual_translations/es/550000.es
#   inflating: /content/dev/550000/manual_translations/de/550000.de
#   inflating: /content/dev/550000/manual_translations/de/550000.docx
#   inflating: /content/dev/550000/manual_translations/de/550000.en
#   inflating: /content/dev/550000/manual_translations/de/550000.lst

# %%
# load dict
import pickle
with open('/content/drive/MyDrive/images_descriptions.pkl', 'rb') as f:
    DESCRIPTIONS = pickle.load(f)
DESCRIPTIONS
# Out:
# {'404': ['1) Título/tema: La diapositiva se titula "Welcome!" y se trata de una sesión de aprendizaje en línea que comienza a las 18:15 horas CET.\n2) 2–3 ideas clave: La diapositiva informa que la sesión es CME acreditada y que al final de la presentación, los participantes serán dirigidos a la evaluación y prueba de opción múltiple.\n3) Elementos visuales: La diapositiva contiene un logotipo en la esquina superior derecha, un cuadro de diálogo en la parte inferior con opciones de "Yes" y "No" para unirse a la conferencia, y un hashtag "#e_ESO" en la parte inferior.',
#   '1) Título/tema: La diapositiva se titula "e-sesion 404" y discute el impacto de la cirugía oncológica en los resultados.\n2) 2–3 ideas clave: La diapositiva presenta a dos expertos, Prof. Charles M. Balch y Prof. Riccardo Audisio, que discuten este tema. También menciona que el contenido de la diapositiva se extrajo de la política de e-ESO, que proporciona nuevas habilidades y conocimientos para oncólogos y otros médicos interesados en oncología.\n3) Elementos visuales: La diapositiva no contiene gráficos, fórmulas o esquemas.',
#   '1) Título/tema: La diapositiva se centra en el tema "THE IMPACT OF ONCOLOGICAL SURGERY ON THE OUTCOMES". El tema se presenta en un tono serio y profesional, con un fondo azul oscuro y texto en amarillo y blanco.\n\n2) 2–3 ideas clave: La diapositiva no contiene ninguna información adicional o ideas clave, ya que el texto legible está oculto. No se pueden identificar ninguna gráfica, fórmulas o esquemas en la diapositiva.\n\n3) Elementos visuales: La diapositiva no contiene ningún elemento visual, ya que el texto legible está oculto. No se pueden identificar ninguna gráfica, fórmulas o esquemas en la diapositiva.',
#   '1) Título/tema: La diapositiva se titula "Global Surgery 2030: evidencia y soluciones para lograr salud, bienestar y desarrollo económico". El tema se centra en los avances en salud global y las soluciones para mejorar el acceso a la atención médica, especialmente en países en desarrollo.\n\n2) 2-3 ideas clave: La diapositiva destaca que, aunque se han hecho progresos en la salud global en los últimos 25 años, no todos los países han tenido acceso a la atención médica. Se menciona que 5 mil millones de personas no tienen acceso a atención médica de calidad, y que el acceso a la atención médica es peor en países de ingresos bajos y medios. También se menciona que se necesitan 143 millones de procedimientos adicionales cada año para salvar vidas y prevenir discapacidades.\n\n3) Elementos visuales: La diapositiva no contiene gráficos, fórmulas o esquemas. Sin embargo, hay una cita destacada en negrita que enfatiza la importancia del acceso a la atención médica para reducir la mortalidad y la morbidez. También hay logos de CrossMark y Lancet en la parte superior derecha de la diapositiva.',
#   '1) Título/tema: La diapositiva se titula "THE LANCET Oncology" y se centra en el tema de la cirugía de cáncer a nivel global, enfatizando la importancia de la cirugía en el control del cáncer a nivel nacional e internacional.\n\n2) 2–3 ideas clave: La diapositiva destaca la necesidad de proporcionar cirugía de cáncer que sea segura, asequible y de alta calidad. También menciona que la cirugía es esencial para el control del cáncer a nivel global y debe ser una parte integral de los planes de control del cáncer a nivel nacional e internacional.\n\n3) Elementos visuales: La diapositiva incluye una imagen de dos cirujenos trabajando juntos en un paciente, lo que enfatiza la importancia de la cirugía en el tratamiento del cáncer. También hay un texto que dice: "Surgery is essential for global cancer care... [and] must be at the heart of global and national cancer control planning."',
#   '1) Título/tema: La diapositiva se centra en la importancia de la cirugía en el tratamiento de la cáncer, con un enfoque en la necesidad de mejorar la accesibilidad y la calidad de la cirugía en todo el mundo para el año 2030.\n\n2) 2-3 ideas clave: La diapositiva destaca que la cirugía es esencial para el tratamiento del cáncer en todos los recursos, y que en 2030 se estima que se necesitarán 45 millones de procedimientos quirúrgicos. Sin embargo, actualmente menos del 25% de los pacientes con cáncer reciben cirugía segura, asequible y oportuna. La diapositiva también menciona que la Comisión de Oncología de la Organización Mundial de la Salud (WHO) ha analizado la situación de la cirugía en el cáncer y ha identificado brechas económicas y equidad en el acceso a la cirugía.\n\n3) Elementos visuales: La diapositiva no contiene gráficos, fórmulas o esquemas, pero sí incluye una lista de autores y una cita destacada en negrita que enfatiza la necesidad de mejorar la cirugía en el futuro.',
#   '1) Título/tema: La diapositiva se centra en "The Lancet Oncology Commission", discutiendo los problemas y soluciones relacionados con el acceso a la cirugía, la inversión en sistemas quirúrgicos públicos, la investigación y la educación en el campo de la oncología.\n\n2) 2–3 ideas clave: La diapositiva destaca dos puntos principales: los problemas que enfrentan los sistemas de oncología, como la falta de acceso a la cirugía, la inversión insuficiente en sistemas quirúrgicos públicos, la investigación y la educación, y las soluciones propuestas para mejorar la situación, como la regulación mejorada de los sistemas públicos, la colaboración internacional, la centralización de los servicios quirúrgicos, la realización de nuevos ensayos clínicos y la adopción de nuevas estrategias para mejorar la calidad y la escalabilidad de los sistemas quirúrgicos a través de la educación y la capacitación.\n\n3) Elementos visuales: La diapositiva no contiene gráficos, fórmulas o esquemas. El texto está centrado y en negrita, lo que indica su importancia. La diapositiva tiene un fondo azul oscuro y el texto está en blanco, lo que crea un contraste que facilita la lectura.',
#   '1) Título/tema: La diapositiva se centra en la "Comisión de Oncología de Lantec", que discute la importancia de la especialización y la calidad en la cirugía de cáncer.\n\n2) 2–3 ideas clave: La comisión reconoce que la cirugía de cáncer es técnicamente demandante y que los resultados mejoran cuando se realiza en centros de alta demanda. También destaca la necesidad de acceso a entrenamiento de alta calidad para cirujanos oncólogos, que aún no se ha formalizado en muchos países.\n\n3) Elementos visuales: La diapositiva no contiene gráficos, fórmulas o esquemas, solo texto en formato de lista con viñetas.',
#   '1) Título/tema: La diapositiva se centra en "THE LANCET ONCOLOGY COMMISSION" y discute la necesidad de entrenar a los cirujanos con un enfoque más amplio debido a la especialización creciente en países de alto ingreso.\n\n2) 2-3 ideas clave: La diapositiva destaca que los países de alto y medio ingreso tienen un papel crucial en expandir las ofertas educativas sobre cirugía de cáncer a los países de bajo ingreso. Sugiere que esto se puede lograr a través de intercambios bilaterales, el uso de tecnología para el aprendizaje y la formación de asociaciones para desarrollar contenido curricular específico sobre cáncer en programas de residencia en cirugía.\n\n3) Elementos visuales: La diapositiva no contiene gráficos, fórmulas o esquemas. El texto está centrado y en negrita, lo que indica su importancia. La diapositiva tiene un fondo azul oscuro y el texto es blanco, lo que crea un contraste claro para la legibilidad.',
#   '1) Título/tema: La diapositiva presenta una colección de logos de diversas organizaciones relacionadas con la oncología y la cirugía. Cada logo representa una entidad diferente que contribuye al campo de la salud, específicamente en el tratamiento y la investigación de enfermedades como el cáncer.\n\n2) 2–3 ideas clave: La diapositiva destaca la colaboración y el intercambio de conocimientos entre diferentes sociedades y asociaciones internacionales. Las organizaciones mencionadas, como la Sociedad de Oncología (SSO), la Asociación para la Cirugía de Cáncer (BASO) y la Sociedad Europea de Oncología (ESO), son reconocidas por su trabajo en mejorar la calidad de la atención y los resultados en el tratamiento del cáncer.\n\n3) Elementos visuales: La diapositiva no contiene gráficos, fórmulas o esquemas. En su lugar, presenta una serie de logos que representan a las organizaciones mencionadas. Cada logo es distintivo y refleja la identidad y los objetivos de la entidad que representa. La diapositiva es visualmente clara y organizada, permitiendo a los espectadores identificar rápidamente las organizaciones involucradas en la oncología.',
#   '1) Título/tema: La diapositiva discute por qué los cirujés necesitan especializarse o subspecializarse, enfocándose en el campo de la oncología.\n\n2) 2-3 ideas clave: La diapositiva destaca los avances rápidos en la investigación de cáncer, los avances en tecnologías quirúrgicas, los cambios en la entrega de cuidados de cáncer a través de centros especializados y la evidencia de que los centros de cáncer de alto volumen y especialistas quirúrgicos tienen mejores resultados para tratar cánceres complejos.\n\n3) Elementos visuales: La diapositiva no contiene gráficos, fórmulas o esquemas. El texto está centrado y en negrita, con viñetas para organizar la información. El fondo es azul oscuro y el texto es blanco, lo que crea un contraste claro para la legibilidad.',
#   '1) Título/tema: La diapositiva discute la importancia de la atención especializada en el tratamiento de la cáncer de mama y cómo mejora la supervivencia de los pacientes.\n\n2) 2–3 ideas clave: La diapositiva presenta datos de un estudio que muestran que los pacientes con cáncer de mama tratados en unidades especializadas tienen un riesgo significativamente menor de recibir tratamiento inadecuado en comparación con aquellos tratados en unidades no especializadas. Además, se destaca que la supervivencia local y la mortalidad en estas unidades especializadas son más altas.\n\n3) Elementos visuales: La diapositiva no contiene gráficos, fórmulas o esquemas, solo texto en formato de lista con viñetas.',
#   '1) Título/tema: La diapositiva discute la supervivencia a largo plazo después de la cirugía para el cáncer de mama, enfocándose en la importancia de la experiencia del cirujano y su especialización en oncología.\n\n2) 2–3 ideas clave: La experiencia del cirujano es crucial para la supervivencia a largo plazo, con un mayor volumen de operaciones por año resultando en una mejor supervivencia. Además, la especialización en oncología puede reducir en un 36% el riesgo de muerte a los 5 años después de la cirugía.\n\n3) Elementos visuales: La diapositiva no contiene gráficos, fórmulas o esquemas, pero presenta texto en formato de viñetas y una cita de referencia.',
#   '1) Título/tema: La diapositiva presenta un estudio sobre la mortalidad en hospitales y la mortalidad en cirugía en los Estados Unidos, publicado en The New England Journal of Medicine.\n\n2) 2–3 ideas clave: El estudio muestra que la mortalidad en cirugía es mayor en hospitales con un volumen de procedimientos por año más alto. También se observa que la mortalidad en cirugía es mayor en hospitales con un volumen de procedimientos por año más alto.\n\n3) Elementos visuales: La diapositiva contiene varias gráficas que muestran la mortalidad en diferentes tipos de procedimientos quirúrgicos en función del volumen de procedimientos por año. Las gráficas muestran que la mortalidad es mayor en hospitales con un volumen de procedimientos por año más alto.',
#   '1) Título/tema: La diapositiva presenta un estudio sobre la relación entre el volumen de cirugía y la mortalidad operativa en los Estados Unidos. El estudio se centra en tres tipos de procedimientos quirúrgicos: resection for lung cancer, cistectomía y esophagectomía, y pancreatectomía.\n\n2) 2–3 ideas clave: El estudio muestra que la mortalidad operativa aumenta con el volumen de cirugía. Por ejemplo, en la resection for lung cancer, la mortalidad operativa es de 6.1% para un volumen de cirugía de menos de 7.0, 5.6% para un volumen de 7.0-17.0 y 5.0% para un volumen de más de 17.0. Similarmente, en la cistectomía, la mortalidad operativa es de 5.5% para un volumen de cirugía de menos de 2.0, 5.3% para un volumen de 2.0-3.5 y 3.1% para un volumen de más de 3.5. En la esophagectomía, la mortalidad operativa es de 18.8% para un volumen de cirugía de menos de 2.0, 13.1% para un volumen de 2.0-6.0 y 9.2% para un volumen de más de 6.0. Finalmente, en la pancreatectomía, la mortalidad operativa es de 14.7% para un volumen de cirugía de menos de 2.0, 8.5% para un volumen de 2.0-4.0 y 4.6% para un volumen de más de 4.0.\n\n3) Elementos visuales: La diapositiva presenta un gráfico de barras que muestra la mortalidad operativa en porcentaje en función del volumen de cirugía. El gráfico tiene cuatro conjuntos de barras, cada uno correspondiente a un tipo de procedimiento quirúrgico. Las barras están coloreadas de manera diferente para cada procedimiento, lo que facilita la comparación entre ellos. El gráfico también incluye una leyenda que explica la coloración de las barras y la escala de mortalidad operativa.',
#   '1) Título/tema: Uso de Q&A en WebEx\n2) 2–3 ideas clave: \n* Los participantes pueden enviar preguntas y comentarios en tiempo real durante la reunión.\n* La función Q&A permite a los usuarios interactuar con el contenido de la presentación y con los demás participantes.\n* La función Q&A también puede ser utilizada para compartir experiencias y conocimientos.\n3) Elementos visuales: \n* La diapositiva muestra una captura de pantalla de la interfaz de WebEx con la función Q&A activa.\n* Hay una barra de herramientas con la opción Q&A resaltada en color rojo.\n* Hay una barra de texto con la opción "Ask: All Panelists" seleccionada.\n* Hay un botón de envío para enviar las preguntas y comentarios.',
#   '1) Título/tema: La diapositiva se centra en la importancia de la volumen en un contexto específico, aunque el título "Volume Isn\'t Most Important" sugiere que el volumen no es el factor más crucial.\n\n2) 2-3 ideas clave: La diapositiva presenta una gráfica de barras que compara dos categorías: "Patient risk factors" y "Hospital". La categoría "Patient risk factors" tiene un porcentaje mucho más alto, alrededor del 90%, mientras que "Hospital" tiene un porcentaje mucho más bajo, alrededor del 10%.\n\n3) Elementos visuales: La gráfica es una representación de barras verticales, con dos barras diferentes de color azul claro. La barra de "Patient risk factors" es mucho más alta que la de "Hospital". La escala de porcentaje está en el lado izquierdo de la gráfica, con marcas de 10% cada una, y la escala de porcentaje está en el lado derecho, con marcas de 10% cada una.',
#   '1) Título/tema: La diapositiva presenta una serie de imágenes que muestran diferentes tipos de lesiones o condiciones de la piel. Las imágenes parecen ser de un contexto médico o de investigación, posiblemente relacionadas con la dermatología o la cirugía.\n\n2) 2–3 ideas clave: Las imágenes destacan la importancia de la visualización en la comprensión de las condiciones de la piel. Las imágenes muestran lesiones con diferentes colores, tamaños y formas, lo que sugiere que la identificación y el tratamiento de estas condiciones pueden variar ampliamente.\n\n3) Elementos visuales: No hay gráficos, fórmulas o esquemas presentes en la diapositiva. Las imágenes son puramente fotográficas y muestran lesiones de la piel en diferentes etapas o tipos. La imagen en la esquina inferior derecha muestra una lesión con una apariencia más suave y menos sangrado, mientras que las imágenes en la esquina superior izquierda muestran lesiones con más sangre y posiblemente en etapas más avanzadas.',
#   '1) Título/tema: La diapositiva presenta un gráfico de barras que muestra la mortalidad postoperatoria para diferentes tipos de cáncer en diferentes tipos de hospitales.\n2) 2–3 ideas clave: El gráfico muestra que la mortalidad postoperatoria es similar en todos los tipos de hospitales para los tipos de cáncer mencionados.\n3) Elementos visuales: El gráfico tiene cuatro categorías de riesgo: "High Risk", "Moderate Risk", "Low Risk" y "Highest Risk". Cada categoría tiene tres barras representando los tipos de hospitales: "Specialized Center", "Other Academic" y "Community Hospitals". El eje vertical representa la mortalidad postoperatoria, que varía de 0% a 20%.',
#   '1) Título/tema: La diapositiva presenta un análisis comparativo de la mortalidad postoperatoria en diferentes tipos de hospitales para pacientes de alto riesgo.\n2) 2–3 ideas clave: La mortalidad postoperatoria es significativamente más alta en centros especializados en comparación con otras instituciones académicas y hospitales comunitarios, especialmente para pacientes de alto riesgo.\n3) Elementos visuales: La diapositiva incluye un gráfico de barras que muestra la mortalidad postoperatoria en porcentajes para los cuatro grupos de riesgo. Cada grupo de riesgo tiene tres barras representando los tres tipos de hospitales. Las barras están coloreadas de manera diferente para cada tipo de hospital, lo que facilita la comparación entre ellos. Además, hay anotaciones de P que indican la significancia estadística de los resultados.',
#   '1) Título/tema: La diapositiva presenta un análisis comparativo de la mortalidad postoperatoria en pacientes con pancreas y esófago, según el tipo de centro médico (centros especializados, otros académicos y hospitales comunitarios) y el riesgo de enfermedad (máximo, alto, moderado y bajo).\n\n2) 2–3 ideas clave: La mortalidad postoperatoria es mayor en centros especializados para pacientes con alto y moderado riesgo, mientras que es menor en centros especializados para pacientes con bajo riesgo. La mortalidad postoperatoria es mayor en otros académicos para pacientes con alto y moderado riesgo, mientras que es menor en otros académicos para pacientes con bajo riesgo. La mortalidad postoperatoria es mayor en hospitales comunitarios para pacientes con alto y moderado riesgo, mientras que es menor en hospitales comunitarios para pacientes con bajo riesgo.\n\n3) Elementos visuales: La diapositiva incluye un gráfico de barras que muestra la mortalidad postoperatoria en porcentajes para cada tipo de centro médico y cada nivel de riesgo. El gráfico tiene cuatro grupos de barras, cada uno representando un nivel de riesgo (máximo, alto, moderado y bajo). Cada grupo de barras tiene tres barras, cada una representando un tipo de centro médico (centros especializados, otros académicos y hospitales comunitarios). El gráfico también incluye anotaciones de significación estadística (P<0.001) para los grupos de barras con mayor mortalidad postoperatoria.',
#   '1) Título/tema: La diapositiva presenta la "Ligame entre Casos de Pancreatectomía y su Impacto en el Resultado", destacando la relación entre el volumen de casos tratados y la mortalidad asociada.\n\n2) 2–3 ideas clave: La diapositiva muestra tablas con datos sobre el número de hospitales y cirujías realizadas por año, así como la mortalidad porcentual. Se resalta la mortalidad en los grupos de hospitalizaciones con más de 16 casos por año y cirugías con más de 4 casos por año.\n\n3) Elementos visuales: La diapositiva incluye dos tablas con datos numéricos y porcentuales. Las tablas están organizadas en filas y columnas, con colores alternados para mejorar la legibilidad. Las referencias a las fuentes de los datos están incluidas en la parte inferior de la diapositiva.',
#   '1) Título/tema: La diapositiva discute la mejora en la calidad quirúrgica en los hospitales participantes en el programa de Mejora de la Calidad Quirúrgica del Colegio Americano de Surgeones.\n\n2) 2–3 ideas clave: El 66% de los hospitales mejoraron la mortalidad y el 82% mejoró la morbilidad. Los cirujas con desempeño peor tuvieron una mayor probabilidad de mejorar, así como los cirujas con desempeño bueno. El número de cirujas con desempeño bajo aumentó, mientras que el número de cirujas con desempeño alto disminuyó. Los hospitales evitaron un estimado de 250 complicaciones por año.\n\n3) Elementos visuales: La diapositiva no contiene gráficos, fórmulas o esquemas.',
#   '1. Título/tema: Uso de Q&A en Cisco WebEx\n2. 2-3 ideas clave: \n* Importancia de las opiniones de los participantes\n* Cómo usar la función Q&A en Cisco WebEx\n* Cómo compartir experiencias con #e_ESO\n3. Elementos visuales: \n* Diagrama de la interfaz de Cisco WebEx\n* Capturas de pantalla de la función Q&A\n* Icono de hashtag #e_ESO',
#   '- Título/tema: La diapositiva se centra en el tema de "THE TRAINING OF ONCOLOGIC SURGEONS".\n- 2-3 ideas clave: La diapositiva no contiene ninguna información adicional o ideas clave, ya que solo presenta el título del tema.\n- Elementos visuales: No hay gráficos, fórmulas o esquemas presentes en la diapositiva, solo texto en formato de viñeta.',
#   '1) Título/tema: La diapositiva presenta los requisitos de la American Board of Surgery para la formación en cirugía general.\n2) 2–3 ideas clave: La formación en cirugía general incluye una variedad de especialidades como el tracto alimenticio, abdomen, sistema endocrino, cirugía de trasplante solidario, cirugía pediátrica, cirugía crítica, cirugía oncológica, cirugía de trauma y cirugía vascular.\n3) Elementos visuales: La diapositiva no contiene gráficos, fórmulas o esquemas, solo texto en formato de lista con viñetas.',
#   '1) Título/tema: La diapositiva se centra en la propuesta de un currículo global para la oncología quirúrgica, con un enfoque en la variación en la formación de oncólogos y la necesidad de un currículo internacional.\n\n2) 2–3 ideas clave: La diapositiva presenta dos artículos de la revista "Annals of Surgical Oncology" que discuten la variación en la formación de oncólogos y la propuesta de un currículo global. Los autores de los artículos son C. Are, MD, MBA, FRCS, FACS, A. Cariglia, BS, M. Malik, BS, C. Cummings, RN, PhD, CCMEP, C. Lecoq, B.Ed, EMIAM, R. Berman, MD, FRCS, R. Audisio, MD, FRCS, y L. Wyld, BMedSci, MBChB (Hons), PhD, FRCS. Los artículos discuten la importancia de un currículo global para la oncología quirúrgica y la variación en la formación de oncólogos.\n\n3) Elementos visuales: La diapositiva contiene dos imágenes de los autores de los artículos, pero no hay gráficos, fórmulas o esquemas presentes.',
#   '1) Título/tema: La diapositiva discute las características distintivas de un cirujano oncólogo.\n2) 2-3 ideas clave: Un cirujano oncólogo es un excelente cirujano que puede manejar a los pacientes con cáncer a través de operaciones complejas y tiene la capacidad de decidir qué operaciones realizar. También conoce cómo integrar el tratamiento quirúrgico como parte de un equipo multidisciplinario, incluyendo la planificación de la cirugía después de terapias sistémicas y/o terapia de radiación. Además, participa como oncólogo en la gestión a largo plazo del cáncer de los pacientes.\n3) Elementos visuales: No hay elementos visuales como gráficos, fórmulas o esquemas en la diapositiva.',
#   'La diapositiva muestra una página web de la American Board of Surgery (ABS) con información sobre un nuevo certificado en compleja oncología general. El título de la página es "ABS Announces New Certificate in Complex General Surgical Oncology". La página incluye un resumen del anuncio, que menciona que el ABS ha recibido aprobación para ofrecer un nuevo subspecialty certificado en oncología general compleja. El resumen también menciona que el certificado se ofrecerá a graduados de programas de entrenamiento acreditados por la Accreditation Council for Graduate Medical Education (ACGME) y que los graduados tendrán conocimientos específicos para tratar casos complejos de cáncer. La página también incluye enlaces a otras secciones de la página web, como "My Records/My Account", "ABS Exam Information", "General Surgery", "Vascular Surgery", "Pediatric Surgery", "Surgical Critical Care", "Other Specialties", "Maintenance of Certification (MOC)", "Training Programs", "News", "About the ABS", "Publications" y "For Public/Patients". No hay elementos visuales como gráficos, fórmulas o esquemas en la diapositiva.',
#   '1) Título/tema: La diapositiva presenta los componentes principales de un programa de entrenamiento de dos años en cirugía oncológica.\n2) 2–3 ideas clave: El programa incluye la atención multidisciplinaria en el cuidado de los pacientes con cáncer, la gestión quirúrgica de las condiciones oncológicas, las modalidades no quirúrgicas de tratamiento del cáncer, la asesoría al paciente sobre intervenciones preventivas de cáncer y la investigación clínica y diseño de ensayos.\n3) Elementos visuales: La diapositiva no contiene gráficos, fórmulas o esquemas.',
#   '1) Título/tema: La diapositiva se centra en el "Ultrasonografía guiada de la aguja de core", un procedimiento médico utilizado en el campo de la oncología para realizar biopsias guiadas por ultrasonografía.\n\n2) 2–3 ideas clave: La diapositiva muestra una imagen de ultrasonografía que parece ser el resultado de una biopsia guiada. También incluye una imagen de un profesional de la salud realizando la biopsia con una aguja guiada por ultrasonografía. Además, se menciona que un 80% de los oncólogos quirúrgicos ahora utilizan ultrasonografía en sus procedimientos.\n\n3) Elementos visuales: La diapositiva contiene dos imágenes: una de una ultrasonografía y otra de un profesional de la salud realizando una biopsia con una aguja guiada por ultrasonografía. También hay texto que proporciona información sobre el uso de la ultrasonografía en la oncología.',
#   '1) Título/tema: La diapositiva se titula "Pre-operativo Chemoterapia", lo que indica que se trata de una preparación para una cirugía mediante la administración de quimioterapia antes del procedimiento.\n\n2) 2–3 ideas clave: La diapositiva muestra dos imágenes de una persona con quimioterapia. En la primera imagen, la persona no tiene ningún dispositivo de quimioterapia, mientras que en la segunda imagen, la persona tiene un dispositivo de quimioterapia en su pecho. Esto sugiere que la diapositiva se centra en la aplicación de quimioterapia como parte de la preparación para una cirugía.\n\n3) Elementos visuales: La diapositiva contiene dos imágenes de una persona con quimioterapia. Las imágenes muestran la aplicación de un dispositivo de quimioterapia en el pecho de la persona. No hay gráficos, fórmulas o esquemas en la diapositiva.',
#   '1) Título/tema: La diapositiva se titula "NEOADJUVANT THERAPY: THIS IS THE FUTURE!" y se centra en el tema de la terapia de neoadjuvantia, que es un tratamiento médico que se utiliza antes de una cirugía, especialmente en el tratamiento del cáncer.\n\n2) 2-3 ideas clave: La diapositiva presenta una imagen de rayos X que muestra una área de tejido en el cuerpo, posiblemente un tumor. La imagen sugiere que la terapia de neoadjuvantia es una opción de tratamiento para el cáncer, ya que se utiliza para reducir el tamaño del tumor antes de que se realice la cirugía. La frase "THIS IS THE FUTURE!" implica que la terapia de neoadjuvantia es una técnica prometedora y que se espera que se vuelva más común en el futuro.\n\n3) Elementos visuales: La diapositiva contiene una imagen de rayos X que muestra una área de tejido en el cuerpo, posiblemente un tumor. La imagen está en blanco y negro, y el texto está en blanco sobre un fondo negro. La diapositiva también incluye un número, "33", que podría indicar el número de la diapositiva en un conjunto de diapositivas.',
#   '1) Título/tema: La diapositiva muestra un caso de neoadjuvant anti-PD1 inmunoterapia para un paciente con melanoma avanzado.\n2) 2–3 ideas clave: La imagen compara los resultados de la biopsia del paciente antes y después de la inmunoterapia. Antes de la terapia, el melanoma está más extendido y agresivo. Después de la terapia, el melanoma ha disminuido en tamaño y agresividad, lo que indica una respuesta positiva a la inmunoterapia.\n3) Elementos visuales: La diapositiva contiene dos imágenes de tomografía computarizada (TC) que muestran el estado del melanoma antes y después de la inmunoterapia. Las imágenes están marcadas con círculos rojos para resaltar el área afectada por el melanoma. La imagen también incluye una fecha, "July 2014 (Post-BRAF/MEK)", que indica cuándo se tomaron las imágenes.',
#   '1) Título/tema: La diapositiva se centra en el tema de "FUTURE OF CANCER SYSTEMIC THERAPY", lo que sugiere un enfoque en los tratamientos futuros para el cáncer sistémico.\n\n2) 2–3 ideas clave: La diapositiva presenta varios medicamentos utilizados en el tratamiento del cáncer, como Tarceva (erlotinib), Gleevec (imatinib mesylate), Arimidex (anastrozole), Sytromon (silybum extractum), Tykerb (lapatinib), y Verve (vermeflexin). Estos medicamentos son conocidos por su uso en el tratamiento de ciertos tipos de cáncer, como el cáncer de mama, el cáncer de próstata y el cáncer de pulmón.\n\n3) Elementos visuales: La diapositiva incluye imágenes de cajas de medicamentos, tabletas y un usuario tomando una pastilla. También hay una imagen de una página web, lo que podría indicar que la diapositiva se basa en información o recursos en línea. No hay gráficos, fórmulas o esquemas presentes en la diapositiva.',
#   '1) Título/tema: La diapositiva presenta una lista de ejemplos de nuevos agentes para el tratamiento de cáncer oral o subcutáneo.\n2) 2–3 ideas clave: La diapositiva destaca que hay más de 1000 nuevos medicamentos en desarrollo para el tratamiento del cáncer, lo que indica un avance significativo en la investigación y la medicina.\n3) Elementos visuales: No hay gráficos, fórmulas o esquemas en la diapositiva, solo una lista de nombres de medicamentos en formato de viñetas.',
#   '1) Título/tema: La diapositiva se centra en la respuesta metabólica a la administración de Vemafinib, un inhibidor de BRAF, en un paciente con mutación V600E+ en melanoma metastático.\n\n2) 2–3 ideas clave: La diapositiva muestra dos imágenes de un paciente, una tomada el día 1 y la otra el día 15, después de recibir Vemafinib. Las imágenes muestran la distribución de la radioligada en el cuerpo del paciente, lo que indica la presencia de melanoma metastático. La imagen del día 15 muestra una distribución más concentrada y reducida en comparación con la imagen del día 1, lo que sugiere una respuesta positiva a la terapia.\n\n3) Elementos visuales: Las imágenes son de rayos X con contraste, mostrando la distribución de la radioligada en el cuerpo del paciente. Las imágenes están etiquetadas con "Day 1" y "Day 15" para indicar el tiempo de la administración de la radioligada. La diapositiva también incluye texto que describe el tema y la fuente de las imágenes.',
#   '1) Título/tema: La diapositiva presenta una lista de tipos de cáncer donde se ha demostrado la actividad de un inhibidor en estudios clínicos.\n\n2) 2–3 ideas clave: La lista incluye varios tipos de cáncer como Melanoma, Lung Cancer, Head and Neck Cancer, entre otros. También se menciona que el inhibidor ha demostrado actividad en estos casos.\n\n3) Elementos visuales: No hay gráficos, fórmulas o esquemas en la diapositiva, solo texto en formato de lista.',
#   '1) Título/tema: La diapositiva se centra en la respuesta de un caso de metástasis de melanoma en el pecho a una dosis de inmunoterapia con Ipilimumab y Nivolumab.\n\n2) 2–3 ideas clave: La diapositiva muestra una serie de imágenes que ilustran el progreso del melanoma en el paciente. Comienza con una imagen de un melanoma en la piel, seguido de una imagen de un melanoma en la boca. Luego se muestran dos imágenes de rayos X que muestran la presencia del melanoma en el pecho.\n\n3) Elementos visuales: La diapositiva incluye imágenes de alta resolución de un melanoma en la piel y en la boca, así como dos rayos X que muestran la presencia del melanoma en el pecho. Las imágenes son claras y detalladas, lo que permite una visualización precisa de la ubicación y extensión del melanoma.',
#   '1) Título/tema: La diapositiva trata sobre el tratamiento del cáncer de la expresidenta de los Estados Unidos, Jimmie Carter, quien ha sido tratada con un nuevo medicamento llamado pembrolizumab.\n\n2) 2–3 ideas clave: La diapositiva destaca que Jimmie Carter, a la edad de 92 años, ha logrado un remisión de 16 meses después de recibir el tratamiento con pembrolizumab. También menciona que el medicamento es uno de los más prometedores en el tratamiento de la enfermedad.\n\n3) Elementos visuales: La diapositiva contiene dos imágenes de Jimmie Carter en un entorno de conferencia, con una cita que dice "PAIN HAS BEEN \'SLIGHT,\' HAVEN\'T FELT WEAKNESS". Además, hay una cita de un artículo que dice "New immunotherapy drug behind Jimmy Carter\'s cancer cure" y otra que dice "Former president given pembrolizumab, one of the most promising new drugs in the treatment of cancer".',
#   '1) Título/tema: La diapositiva muestra la respuesta de un paciente con cáncer de cabeza y cuello que está recibiendo terapia anti-PD-L1 (MEDI4736). Se compara la condición del paciente en la etapa inicial (Baseline) y en la etapa 28 días después de iniciar la terapia.\n\n2) 2–3 ideas clave: El paciente es una mujer de 96 años que progresó en su tratamiento con cetuximab anterior y tiene un resultado de prueba positiva para PD-L1. La terapia anti-PD-L1 se está llevando a cabo en la octava semana del tratamiento.\n\n3) Elementos visuales: La diapositiva incluye dos imágenes de la parte superior del cuerpo del paciente, mostrando la cabeza y el cuello. En la imagen de la etapa inicial, el paciente tiene una masa en la cabeza, mientras que en la imagen de la etapa 28 días después, la masa parece haber disminuido en tamaño. Además, hay una anotación que indica una respuesta preliminar del 14% en pacientes con cáncer de cabeza y cuello avanzado.',
#   '1) Título/tema: La diapositiva se centra en la importancia de la educación continua para los cirujanos practicantes, especialmente en el campo de la cirugía y la oncología.\n\n2) 2-3 ideas clave: La diapositiva destaca la necesidad de mantenerse actualizado con las últimas investigaciones y técnicas en el campo médico. Muestra diferentes formas de educación continua, como reuniones en vivo, afiliaciones académicas, publicaciones en revistas y seminarios web.\n\n3) Elementos visuales: La diapositiva incluye imágenes de una reunión en vivo, logos de instituciones académicas y revistas, y una diapositiva de seminario web. También hay una imagen de una página de correo electrónico con un mensaje sobre el cáncer.',
#   'La diapositiva muestra la portada de dos revistas científicas, "Annals of Surgical Oncology" y "European Journal of Surgical Oncology". Ambas revistas están relacionadas con el campo de la oncología quirúrgica. La portada de "Annals of Surgical Oncology" muestra una imagen de un cirujano trabajando en un paciente, lo que indica que la revista se enfoca en la cirugía y la oncología. La portada de "European Journal of Surgical Oncology" también muestra una imagen de un cirujano trabajando en un paciente, lo que refuerza la idea de que ambas revistas se centran en la cirugía y la oncología. Ambas revistas tienen una apariencia profesional y académica, lo que indica que son publicaciones de alto nivel en el campo de la oncología.',
#   '1) Título/tema: La diapositiva presenta información sobre el programa SOSAP, un programa de autoevaluación para oncólogos.\n\n2) 2-3 ideas clave: El programa SOSAP es una herramienta de aprendizaje basada en casos para mejorar la atención al paciente en oncología. Está diseñado y ofrecido por la Sociedad de Oncología. El programa está disponible en línea 24/7/365 y también como una aplicación para iPad.\n\n3) Elementos visuales: La diapositiva incluye una imagen de un tablet con la marca SOSAP y el logotipo de la Sociedad de Oncología. También hay una barra de navegación en la parte superior de la diapositiva con enlaces a diferentes secciones del sitio web.',
#   '1) Título/tema: La diapositiva se centra en el tema de "Telemedicina en los Estados Unidos", destacando cómo esta tecnología se está integrando en diferentes sectores de la atención médica.\n\n2) 2–3 ideas clave: La telemedicina se está convirtiendo en una parte esencial de la atención médica, con su uso en hospitales, departamentos de especialidades, agencias de salud en el hogar, oficinas de médicos privados y en los hogares y lugares de trabajo de los consumidores.\n\n3) Elementos visuales: La diapositiva incluye imágenes que muestran la telemedicina en acción, con profesionales médicos utilizando tecnología de telemedicina para interactuar con pacientes. Las imágenes ilustran el uso de pantallas y dispositivos de telemedicina en diferentes entornos, como hospitales y consultorios privados.',
#   '1) Título/tema: La diapositiva se centra en las "Servicios que se pueden proporcionar por Telemedicina".\n2) 2-3 ideas clave: La telemedicina ofrece servicios como educación médica y consultas especializadas. La educación médica proporciona créditos para profesionales de la salud y seminarios especializados para grupos específicos en ubicaciones remotas. Las consultas especializadas pueden involucrar a expertos en cáncer que brindan diagnósticos y asesoramiento de tratamiento a médicos en diferentes ubicaciones o naciones.\n3) Elementos visuales: La diapositiva incluye dos imágenes que muestran a profesionales de la salud utilizando tecnología de telemedicina. En la imagen superior, un médico está usando un teleprotocolo para interactuar con un paciente en una cama. En la imagen inferior, un médico está usando un teleprotocolo para interactuar con un paciente en una habitación de hospital.',
#   '1) Título/tema: La diapositiva se centra en la importancia de la consulta con expertos en cáncer en los Estados Unidos y la refuerzo como un paso apropiado en el tratamiento del cáncer.\n\n2) 2-3 ideas clave: La diapositiva destaca la plataforma "CANCER NOW" como un recurso para la colaboración y educación entre expertos en el campo del cáncer. También menciona que las sesiones en esta plataforma se registran.\n\n3) Elementos visuales: La diapositiva incluye el logotipo de "CANCER NOW" y una imagen de una videoconferencia con varios participantes. También hay un botón que dice "Leave the room" y un aviso que indica que la sesión se registrará.',
#   '1) Título/tema: La diapositiva presenta la "CEN Virtual Tumor Board" organizada por Dr. H. Rugo y G. Balch en Hangzhou en febrero de 2017. El tema central es la discusión de un caso de cáncer colorrectal.\n\n2) 2–3 ideas clave: La discusión se lleva a cabo en un entorno virtual, utilizando tecnología de videoconferencia para reunir a expertos en el campo. Se discuten aspectos clínicos y terapéuticos del caso, incluyendo tratamientos y resultados esperados.\n\n3) Elementos visuales: La diapositiva incluye imágenes de una sala de conferencias con una mesa donde se reúnen los participantes, y dos pantallas mostrando a los participantes en una videoconferencia. También hay una imagen de una diapositiva con texto que parece ser parte de la discusión.',
#   '1) Título/tema: La diapositiva se centra en la importancia y efectividad de la "Virtual Tumor Board" en la gestión de pacientes con cáncer, según un estudio realizado en 2016.\n\n2) 2–3 ideas clave: El estudio muestra que un 91% de los participantes encontraron útil la Virtual Tumor Board en la gestión de sus pacientes, y un 100% de los asistentes percibieron una mejora en la calidad de la atención y en su confianza a través de la participación.\n\n3) Elementos visuales: La diapositiva incluye una imagen de un documento con el título "Improving Care Quality with Soft Tissue and Bone Sarcoma by Establishing a National Virtual Tumor Board and Electronic Consultation Platform". También hay una gráfica de pie que muestra la distribución de las respuestas a una pregunta sobre la mejora en la calidad de la atención, con un 100% de participantes respondiendo afirmativamente.',
#   '1. Título/tema: Uso de Q&A en Cisco WebEx\n2. 2-3 ideas clave: \n* Importancia de las opiniones de los participantes\n* Cómo usar la función Q&A para preguntas y comentarios\n* Compartir experiencias e-eso con el hashtag #e_eso\n3. Elementos visuales: \n* Diágrama de la interfaz de Cisco WebEx\n* Capturas de pantalla de la función Q&A\n* Icono del hashtag #e_eso',
#   '1) Título/tema: La diapositiva discute cómo adoptar los cambios en un enfoque de práctica de cáncer en los Estados Unidos.\n\n2) 2–3 ideas clave: \n- La mayoría de los pacientes con cáncer en los Estados Unidos recibirán más de una modalidad de tratamiento, lo que significa que el cuidado del cáncer es un enfoque de equipo.\n- El cáncer se está convirtiendo en una enfermedad crónica o curable, lo que implica la importancia de la supervivencia, las secundarias y la conformidad en el tratamiento.\n- El campo de la oncología es una de las especialidades médicas más rápidamente avanzando y cambiantes, y es importante validar los avances a través de ensayos clínicos.\n- La educación continua del médico es crucial para mantenerse actualizado a lo largo de la vida, a través de organizaciones como SSO, ESSO, ASCO, etc.\n\n3) Elementos visuales: La diapositiva no contiene gráficos, fórmulas o esquemas.',
#   '1) Título/tema: La diapositiva discute la importancia de que los cirujanos especializados mejoren los resultados en el tratamiento de pacientes con cánceres complejos o avanzados.\n\n2) 2-3 ideas clave: \n   - Los cirujanos especializados tienen un mejor desempeño en el tratamiento de cánceres complejos o avanzados.\n   - Hay una demanda de atención médica óptima de especialistas y centros de cánceres multidisciplinarios.\n   - No todos los pacientes con cáncer necesitan ser tratados por especialistas, especialmente si el diagnóstico es temprano y el tratamiento es simple.\n   - Los cirujanos oncológicos deben ser líderes educativos y de investigación en la comunidad de cirugía general.\n\n3) Elementos visuales: \n   - La diapositiva no contiene gráficos, fórmulas o esquemas.',
#   '1) Título/tema: La diapositiva se titula "CONCLUSIONES" y discute la importancia de las sociedades profesionales en el tratamiento y cuidado de los pacientes con cáncer.\n\n2) 2-3 ideas clave: La diapositiva destaca la importancia de las sociedades profesionales como la Sociedad de Oncología, la European SSO, la American College of Surgeons y la American Society of Clinical Oncology en definir estándares de tratamiento para pacientes con cáncer. También enfatiza la importancia de las alianzas entre estas sociedades y las instituciones médicas para acelerar el progreso en el cuidado de los pacientes.\n\n3) Elementos visuales: La diapositiva no contiene gráficos, fórmulas o esquemas. El texto está centrado y en negrita, lo que indica su importancia. El fondo es de color azul oscuro, lo que proporciona un contraste con el texto blanco, haciendo que sea legible.',
#   '1) Título/tema: La diapositiva se titula "E-sesion Question & Answer Session" y se centra en cómo los participantes pueden interactuar durante una sesión de e-sesion.\n2) 2–3 ideas clave: La diapositiva muestra cómo los participantes pueden enviar preguntas y comentarios a través de un botón Q&A. También se muestra cómo se puede seleccionar a los participantes a los que se desea enviar las preguntas.\n3) Elementos visuales: La diapositiva incluye una imagen de una interfaz de usuario con un botón Q&A destacado. También hay una etiqueta con el hashtag #e_eso, que se puede usar para compartir experiencias de e-sesion.',
#   '1) Título/tema: La diapositiva se titula "The next e-ESO Session" y discute los detalles de la próxima sesión de e-ESO, incluyendo la fecha, el número de la sesión y los participantes.\n2) 2–3 ideas clave: La diapositiva proporciona información sobre la próxima sesión de e-ESO, que se llevará a cabo el jueves 20 de julio de 2017. También menciona la sesión 405 y los participantes, Prof. Stefano Luminari y Dr. Astrid Pavlovsky, que discutirán los Highlights de ICML 2017.\n3) Elementos visuales: La diapositiva no contiene gráficos, fórmulas o esquemas. Sin embargo, hay un logotipo en la esquina superior derecha que dice "Learning to care online".'],
#  '596001': ['1) Título/tema: La diapositiva se centra en cómo evaluar la calidad de los planes de tratamiento en radioterapia. Presenta a un experto y un disuciante que discuten este tema.\n\n2) 2-3 ideas clave: El experto, Dr. Núria Jorquet Sala, es del Prostate Institute Barcelona, Barcelona, España. El disuciante es Prof. Pierfrancesco Franco, de la University of Eastern Piedmont, Novara, Italia. La diapositiva discute la importancia de compartir experiencias en e-Eso y cómo usar el hashtag #e_ESO para hacerlo.\n\n3) Elementos visuales: La diapositiva no contiene gráficos, fórmulas o esquemas. Sin embargo, presenta el logo de e-Eso y el hashtag #e_ESO para compartir experiencias en e-Eso.',
#   '1) Título/tema: La diapositiva se centra en cómo evaluar la calidad de los planes de tratamiento en radioterapia. Presenta la información de Nuria Jornet, una consultora médica física y cabeza del departamento de física de radioterapia en el Hospital de la Santa Creu i Sant Pau, Barcelona.\n\n2) 2-3 ideas clave: La diapositiva destaca la importancia de la calidad en los planes de radioterapia y la experiencia de Nuria Jornet en este campo. También menciona que la información se puede obtener a través de las e-sessions de e-ESO.net.\n\n3) Elementos visuales: La diapositiva no contiene gráficos, fórmulas o esquemas. Sin embargo, presenta el logotipo de e-ESO.net y el logotipo de la European School of Oncology, que son visuales relevantes para el tema.',
#   '1) Título/tema: La diapositiva se titula "Objetivos de aprendizaje" y se enfoca en los objetivos de aprendizaje para una sesión de e-SESessions.\n\n2) 2-3 ideas clave: La diapositiva presenta cuatro objetivos de aprendizaje principales. El primer objetivo es proporcionar una visión general del proceso de tratamiento de la RT. El segundo objetivo es analizar diferentes aspectos de la "calidad del plan de tratamiento". El tercer objetivo es evaluar la calidad del plan de tratamiento. El cuarto objetivo es diseñar orientación radiológica para ensayos clínicos y protocolos de tratamiento internos.\n\n3) Elementos visuales: La diapositiva no contiene gráficos, fórmulas o esquemas. Solo contiene texto.',
#   '1) Título/tema: La diapositiva trata sobre el proceso de tratamiento de radioterapia para pacientes, incluyendo los pasos desde la prescripción del tratamiento hasta su entrega.\n\n2) 2–3 ideas clave: La diapositiva destaca la importancia de la planificación del tratamiento, la imagen y la delineación del contorno, y la entrega del tratamiento. También enfatiza la necesidad de verificar si el tratamiento se entrega como planeado y como prescrito.\n\n3) Elementos visuales: La diapositiva incluye una imagen de un paciente, una ilustración de un escáner CT, imágenes de imágenes de rayos X, una imagen de un monitor de rayos X, una imagen de un monitor de rayos X con un contorno delineado, una imagen de un paciente modelado, una imagen de un monitor de rayos X con un modelo de paciente, y una imagen de un paciente dentro de un equipo de radioterapia.',
# ...
#  '592': ['1) Título/tema: TITAN: Thrombocytopenia\n2) 2-3 ideas clave: La diapositiva presenta la información sobre Thrombocytopenia, una condición médica. Presenta a dos expertos, Mr Johan De Munter y Mrs Ana Khmaladze, que discuten sobre este tema. También incluye un extracto de la política de e-ESO, que proporciona información sobre el uso de la plataforma e-ESO para la educación en oncología.\n3) Elementos visuales: La diapositiva no contiene gráficos, fórmulas o esquemas. Contiene solo texto y logos.',
#   '1) Título/tema: TITAN - Programa de Educación y Entrenamiento para Enfermeras\n2) 2-3 ideas clave: El TITAN es un programa educativo diseñado para mejorar las habilidades y conocimientos de las enfermeras al tratar a pacientes con cáncer, trombocitopenia, anemia y neutropenia. El programa está disponible para miembros individuales o nacionales de EONS que deseen organizar un curso TITAN en su país.\n3) Elementos visuales: La diapositiva no contiene gráficos, fórmulas o esquemas.',
#   "1) Título/tema: La diapositiva se centra en el tema de la trombocitopenia en pacientes con cáncer. El título indica que se tratará un 'A-Z' de los aspectos relacionados con esta condición.\n\n2) 2-3 ideas clave: La diapositiva aborda los siguientes puntos clave:\n   - Causas de la trombocitopenia en pacientes con cáncer.\n   - Incidencia de la trombocitopenia en esta población.\n   - Síntomas y signos de la trombocitopenia.\n   - Impacto de la trombocitopenia en el tratamiento y calidad de vida de los pacientes con cáncer.\n   - Manejo y tratamiento de la trombocitopenia en estos pacientes.\n\n3) Elementos visuales: No hay elementos visuales como gráficos, fórmulas o esquemas en la diapositiva. La diapositiva se compone principalmente de texto.",
#   '1) Título/tema: La diapositiva se centra en el tema de la Thrombocytopenia, una condición relacionada con la cantidad de plaquetas circulantes en el cuerpo.\n2) 2–3 ideas clave: La diapositiva define la Thrombocytopenia como una condición donde el número de plaquetas circulantes es inferior a 150 x 10^9/L. También menciona que esta condición puede reducir la coagulación y el riesgo de hemorragia, pero aumenta el riesgo de sangrado cuando el conteo de plaquetas es inferior a 30 x 10^9/L.\n3) Elementos visuales: La diapositiva no contiene gráficos, fórmulas o esquemas, pero utiliza cajas de texto para presentar la información. El diseño es simple y fácil de entender, con un fondo azul y texto en amarillo y negro.',
#   '1) Título/tema: La diapositiva se titula "Signos y síntomas de trombocitopenia", lo que indica que se trata de los signos y síntomas asociados con la trombocitopenia, una condición en la que hay una cantidad reducida de trombocitos en la sangre.\n\n2) 2–3 ideas clave: La diapositiva enumera cuatro signos y síntomas clave de la trombocitopenia: 1) Bleeding, 2) Purpura, ecchymosis (bruising) o haematomas, 3) Headaches, 4) Prolonged menstruation o increased levels of bleeding during menses.\n\n3) Elementos visuales: La diapositiva incluye una imagen de un brazo con un haematoma, que es un signo visual de la trombocitopenia. La imagen muestra un área de la piel con un color rojo oscuro, lo que indica la presencia de sangre bajo la piel.',
#   '1) Título/tema: La diapositiva se centra en las causas generales de la trombocitopenia en pacientes con cáncer, dividiéndolas en dos categorías: enfermedad-inducida y tratamiento-inducido.\n\n2) 2–3 ideas clave: La trombocitopenia puede ser causada por factores de enfermedad como la infiltración de marrozo, diseminación intravascular de coagulación, disfunción de los factores de coagulación, trombocitopenia inmune y trombocitopenia trombótica. También puede ser inducida por tratamientos como la quimioterapia, radioterapia, medicamentos no citotóxicos, la inducción de trombocitopenia por heparina y la trombocitopenia post-transfusional.\n\n3) Elementos visuales: La diapositiva no contiene gráficos, fórmulas o esquemas, pero utiliza viñetas para organizar la información en dos secciones claramente diferenciadas. Cada sección tiene un color de fondo diferente (azul para enfermedad-inducida y amarillo para tratamiento-inducido) para facilitar la lectura y la comprensión.',
#   '1) Título/tema: La diapositiva discute el curso temporal de la trombocitopenia inducida por quimioterapia.\n2) 2–3 ideas clave: La disminución más significativa en el conteo de plaquetas ocurre en las primeras etapas de la quimioterapia, y hay un efecto acumulativo que puede verse a lo largo de varias sesiones. Además, algunos pacientes pueden permanecer refractarios y no recuperar su función plaquetaria.\n3) Elementos visuales: La diapositiva no contiene gráficos, fórmulas o esquemas.',
#   '1) Título/tema: La diapositiva trata sobre la refractoriedad a la transfusión de plaquetas, que es la falla a alcanzar un incremento de plaquetas de 11 x 10^9/L dentro de 1 hora después de una transfusión.\n\n2) 2–3 ideas clave: La refractoriedad a la transfusión de plaquetas puede ser causada por factores no inmunes, como fiebre o hemorragia activa, o por factores inmunes, como HLA alloantibodies. En el caso de factores no inmunes, se recomienda corregir la causa subyacente y transfusar más plaquetas. En el caso de factores inmunes, se recomienda transfusiones de plaquetas HLA compatibles o cruzadas.\n\n3) Elementos visuales: La diapositiva no contiene gráficos, fórmulas o esquemas. Solo contiene texto y una línea de conexión entre los dos tipos de refractoriedad.',
#   '1) Título/tema: La diapositiva se centra en los agentes de terapia dirigida comúnmente asociados con la trombocitopenia, divididos en dos categorías: dosis limitantes a la toxicidad y toxicidad de inicio retrasada.\n\n2) 2–3 ideas clave: La diapositiva enumera varios medicamentos, como ibritumomab tiuxetan y bortezomib, que pueden causar toxicidad potencial o real. También menciona agentes como carmustine y fludarabina que pueden retrasar el inicio de la toxicidad.\n\n3) Elementos visuales: La diapositiva no contiene gráficos, fórmulas o esquemas, pero utiliza viñetas para organizar la información. La fuente de la información se indica en la parte inferior de la diapositiva.',
#   '1) Título/tema: La diapositiva presenta los factores de riesgo para la trombocitopenia y la hemorragia en pacientes con cáncer.\n\n2) 2–3 ideas clave: Los factores de riesgo para la trombocitopenia incluyen la presencia de cáncer con involucramiento óseo, neutropenia severa o febril, tipo de cáncer, tipo de quimioterapia, edad, diabetes, niveles bajos de hemoglobina, niveles bajos de hemoglobina, niveles altos de fosfatasas alcalinas y niveles altos de fosfatasas alcalinas. Los factores de riesgo para la hemorragia incluyen cánceres que requieren tratamiento multimodulidad agresivo, conteo inicial de plaquetas <150 x10^9/L, radioterapia previa, presión arterial alta, aumento de temperatura, constipación, co-morbilidades y cirugía.\n\n3) Elementos visuales: La diapositiva no contiene gráficos, fórmulas o esquemas. Solo contiene texto en formato de lista con viñetas.',
#   '1) Título/tema: La diapositiva se centra en la evaluación de pacientes con sospechas de trombocitopenia, que es una condición en la que hay una deficiencia en el número de plaquetas en la sangre.\n\n2) 2–3 ideas clave: La diapositiva proporciona una guía paso a paso para la evaluación de estos pacientes. Divide la evaluación en tres categorías: historia clínica del paciente, examen físico y pruebas de laboratorio.\n\n3) Elementos visuales: La diapositiva no contiene gráficos, fórmulas o esquemas. Está compuesta principalmente por texto en formato de lista, con viñetas y subviñetas para organizar la información.',
#   '1) Título/tema: La diapositiva presenta una estrategia de gestión de trombocitopenia, que es una condición en la que hay una cantidad insuficiente de plaquetas en la sangre, lo que puede llevar a problemas de coagulación.\n\n2) 2–3 ideas clave: La diapositiva destaca la importancia de monitorear el conteo de plaquetas y la necesidad de ajustar la terapia según los niveles de plaquetas. También menciona la posibilidad de considerar transfusiones de plaquetas en ciertos casos.\n\n3) Elementos visuales: La diapositiva incluye una tabla con diferentes rangos de conteo de plaquetas y las recomendaciones correspondientes para cada rango. También hay una nota al pie que enfatiza que el conteo de plaquetas no es un indicador preciso de riesgo y que se debe evaluar el paciente en un contexto clínico.',
#   '1) Título/tema: La diapositiva discute la transfusión de plaquetas como una medida preventiva para aumentar los conteos de plaquetas y reducir el riesgo de sangrado.\n\n2) 2–3 ideas clave: La diapositiva menciona que la mayoría de las transfusiones de plaquetas se realizan como una medida de prevención para aumentar los conteos de plaquetas y disminuir el riesgo de sangrado. También establece los criterios estándar para la transfusión de plaquetas, como conteos de plaquetas inferiores a 10 x 10^9/L y en pacientes con fibrilación auricular con conteos de plaquetas inferiores a 20 x 10^9/L. Además, señala que los niveles de desencadenante para la transfusión de plaquetas basados en factores de riesgo para el sangrado son controvertidos y que las transfusiones de plaquetas terapéuticas o de menor dosis pueden ser utilizadas para minimizar los riesgos de transfusión.\n\n3) Elementos visuales: La diapositiva no contiene gráficos, fórmulas o esquemas.',
#   '1) Título/tema: La diapositiva discute los riesgos asociados con la transfusión de plaquetas.\n2) 2–3 ideas clave: Los riesgos incluyen aloinmunización, infección, TRALI, reacciones alérgicas y febrilas, y la diferencia entre la enfermedad de Graft versus host y la enfermedad de Graft versus Disease.\n3) Elementos visuales: No hay gráficos, fórmulas o esquemas en la diapositiva.',
#   '1) Título/tema: La diapositiva se centra en las terapias adicionales para la trombocitopenia, que es una condición caracterizada por una baja cantidad de plaquetas en la sangre.\n\n2) 2-3 ideas clave: La diapositiva enumera tres tipos de terapias adicionales para la trombocitopenia: tranexamic acid, factores de crecimiento citocina y agonistas de receptores de trombopoietina.\n\n3) Elementos visuales: La diapositiva no contiene gráficos, fórmulas o esquemas, pero destaca que las transfusiones de plaquetas son la terapia más comúnmente utilizada para tratar la trombocitopenia.',
#   '1) Título/tema: La diapositiva se centra en la minimización del riesgo de complicaciones en pacientes con baja cuenta de plaquetas, utilizando un enfoque colaborativo.\n\n2) 2-3 ideas clave: La diapositiva destaca la importancia de la auto-cuidado, la participación en deportes y actividades, la vigilancia por parte del paciente y su familia, y la educación sobre cómo manejar episodios de sangrado potencial.\n\n3) Elementos visuales: La diapositiva incluye ilustraciones que representan cada una de las ideas clave. Hay una imagen de una persona usando un dispositivo de auto-cuidado, otra de una persona participando en un deporte, una tercera de un grupo de personas observando a un paciente, y una cuarta de una persona con varios elementos circulares que podrían representar la educación sobre la gestión de episodios de sangrado.',
#   '1) Título/tema: La diapositiva se centra en las precauciones de auto-cuidado para minimizar los riesgos de complicaciones en pacientes con baja cuenta de plaquetas, específicamente en el contexto de la trombocitemia.\n\n2) 2–3 ideas clave: La diapositiva proporciona una lista de consejos para el cuidado personal, como evitar objetos afilados, no usar rectales, no tomar rectales, postponer tratamientos como el tatuado o la manicura, usar un cepillo dental suave y consultar a un hematólogo sobre el cuidado dental.\n\n3) Elementos visuales: La diapositiva incluye una ilustración de un personaje que representa un paciente con baja cuenta de plaquetas, mostrando objetos como un cuchillo, un cepillo de dientes y una ampolla de medicamento, lo que enfatiza la importancia de seguir las recomendaciones de auto-cuidado.',
#   '1) Título/tema: La diapositiva trata sobre cómo minimizar los riesgos de complicaciones al realizar actividades adaptadas para personas con baja cuenta de plaquetas, como los pacientes con trombocopenia.\n\n2) 2-3 ideas clave: La diapositiva proporciona consejos sobre cómo realizar actividades como jardinería, cocinar o practicar actividades "do it yourself" de manera segura. También advierte contra actividades que puedan resultar en lesiones, como deportes de contacto, escalar escaleras, hacer ejercicio estrenuo, ciclismo y levantar pesas. Además, ofrece recomendaciones para la actividad sexual, como usar lubricación si es necesario, evitar la penetración anal y evitar la penetración fuerte.\n\n3) Elementos visuales: La diapositiva incluye una ilustración de dos personas en una situación de lucha, que probablemente representa una lesión potencial. También contiene el logotipo de TITAN y el título del libro "Low platelet Count: A Guide for Patients; OncoLink, Low Platelet Count (Thrombocopenia)".',
#   '1) Título/tema: La diapositiva se centra en minimizar los riesgos de complicaciones al alentar la vigilancia del paciente y la familia. Se trata de identificar señales de advertencia que pueden indicar un problema de salud grave.\n\n2) 2–3 ideas clave: La diapositiva enumera varias señales de advertencia, como excesiva sangrado, manchas rojas en la piel, sangrado vaginal, sangrado rectal, sangre en la orina, dolores de cabeza persistentes, visión borrosa, y sangrado constante. También enfatiza la importancia de educar a los pacientes y a sus familias sobre cómo manejar episodios de sangrado.\n\n3) Elementos visuales: La diapositiva incluye una imagen de un hombre y una mujer caminando, que parece representar la vigilancia y el cuidado de la salud. No hay otras gráficas, fórmulas o esquemas presentes en la diapositiva.',
#   '1) Título/tema: La diapositiva se centra en los signos y síntomas que requieren atención médica inmediata en casa, específicamente en el caso de la hemorragia.\n\n2) 2–3 ideas clave: La diapositiva destaca la importancia de buscar atención médica de emergencia en situaciones como signos de shock, cambios visuales, palidez, frío, pulso rápido, hemorragia no controlada y cambios repentinos en la cabeza, la cabeza, la mente o el estado de ánimo.\n\n3) Elementos visuales: La diapositiva incluye una imagen de una casa en un campo, con un símbolo de teléfono rojo indicando la necesidad de llamar a la atención médica. También hay una lista de síntomas con un ícono de teléfono rojo, enfatizando la urgencia de la situación.',
#   '1) Título/tema: La diapositiva se titula "Resumen" y discute el impacto de la trombocitopenia en el riesgo de sangrado y la administración de tratamiento con quimioterapia.\n\n2) 2–3 ideas clave: La diapositiva destaca que la trombocitopenia aumenta el riesgo de sangrado o hemorragia y puede retrasar o reducir la efectividad de la quimioterapia. También enfatiza la importancia de la gestión colaborativa, que incluye identificar el riesgo de los pacientes temprano, monitorear el conteo de plaquetas diariamente y educar a los pacientes sobre la importancia de la autoevaluación diaria y la gestión del sangrado.\n\n3) Elementos visuales: La diapositiva no contiene gráficos, fórmulas o esquemas. Solo contiene texto y logos de la European Oncology Nursing Society y TITAN.']}

# %% [markdown]
# ## 2  Configuración principal

# %%
from transformers import AutoModelForCausalLM, AutoProcessor, GenerationConfig

import torch

model_name = 'microsoft/Phi-4-multimodal-instruct'
processor = AutoProcessor.from_pretrained(model_name,trust_remote_code = True)

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    device_map="cuda",
    torch_dtype=torch.bfloat16,
    trust_remote_code=True,
    # flash_attention_2 eager sdpa
    _attn_implementation='sdpa',
)

generation_config = GenerationConfig.from_pretrained(model_name)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/transformers/models/auto/image_processing_auto.py:594: FutureWarning: The image_processor_class argument is deprecated and will be removed in v4.42. Please use `slow_image_processor_class`, or `fast_image_processor_class` instead
#   warnings.warn(
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.48, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# /root/.cache/huggingface/modules/transformers_modules/microsoft/Phi-4-multimodal-instruct/33e62acdd07cd7d6635badd529aa0a3467bb9c6a/speech_conformer_encoder.py:2774: FutureWarning: Please specify CheckpointImpl.NO_REENTRANT as CheckpointImpl.REENTRANT will soon be removed as the default and eventually deprecated.
#   lambda i: encoder_checkpoint_wrapper(
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# ### 3.1  LoRA

# %%
from peft import LoraConfig, get_peft_model


lora_config = LoraConfig(
    r=8,                         # rango LoRA
    lora_alpha=32,
    lora_dropout=0.05,
    bias="none",
    target_modules=["q_proj","k_proj"]
)
model = get_peft_model(model, lora_config)
model.print_trainable_parameters()
# Out:
# trainable params: 995,328 || all params: 5,575,455,552 || trainable%: 0.0179
# /usr/local/lib/python3.12/dist-packages/peft/mapping_func.py:73: UserWarning: You are trying to modify a model with PEFT for a second time. If you want to reload the model with a different config, make sure to call `.unload()` before.
#   warnings.warn(

# %% [markdown]
# ### 3.2 Data

# %%
from pathlib import Path
import subprocess, soundfile as sf, datetime as dt

FFMPEG = "ffmpeg"          # o la ruta absoluta si no está en PATH

def m4a_to_wav(path_m4a, sr_out=16_000):
    """Convierte 1 × .m4a → .wav (mono, 16 kHz) y devuelve la ruta del WAV."""
    path_m4a = Path(path_m4a)
    wav_path = path_m4a.with_suffix(".wav")
    subprocess.run(
        [FFMPEG, "-loglevel", "error", "-y", "-i", str(path_m4a),
         "-ac", "1", "-ar", str(sr_out), str(wav_path)],
        check=True
    )
    return wav_path



def get_files(folder='test'):
  with open(f'/content/{folder}/{folder}.lst', 'r', encoding='utf-8') as f:
    files = f.read()
    files = files.splitlines()
    print(files)
    return files

# %%
from pathlib import Path
from typing import List, Dict, Tuple, Optional

def _ms_to_seconds(hms: str) -> float:
    m, s, _ = hms.split(":")
    return int(m)*60 + int(s)

def parse_slide_blocks(path: str | Path) -> Dict[str, Dict]:
    """
    Lee un archivo con múltiples bloques:
      <ID> <URL>
      <slide_id|None> <HH:MM:SS>
      ...
    Devuelve dict: { id: {"url": str, "timeline": [(t_sec, slide_id|None), ...]} }
    """
    p = Path(path)
    blocks: Dict[str, Dict] = {}
    cur_id = None
    for line in p.read_text().splitlines():
        line = line.strip()
        if not line:
            continue

        parts = line.split()
        # Cabecera: "<ID> <URL>"
        if len(parts) == 2 and parts[1].startswith("http"):
            cur_id = parts[0]
            blocks[cur_id] = []
            continue

        # Línea de cambio: "<slide_id|None> <HH:MM:SS>"
        if cur_id is not None and len(parts) == 2 and ":" in parts[1]:
            slide_raw, hms = parts
            slide_id = None if slide_raw == "None" else int(slide_raw)
            t = _ms_to_seconds(hms)
            blocks[cur_id].append((t, slide_id))

    # Ordena por tiempo y asegura que hay un evento en t=0
    for k,v in blocks.items():
        v.sort(key=lambda x: x[0])

    return blocks

def build_slide_intervals(timeline: List[Tuple[float, Optional[int]]]) -> List[Dict]:
    """
    Convierte una timeline en intervalos contiguos: [{"start":t0,"end":t1,"slide":id}, ...]
    El último intervalo termina en +inf (None).
    """
    out = []
    for i, (t, slide) in enumerate(timeline):
        t_next = timeline[i+1][0] if i+1 < len(timeline) else None
        out.append({"start": t, "end": t_next, "slide": slide})
    return out

# %%
def slide_at(time_s: float, intervals: List[Dict]) -> Optional[int]:
    """Devuelve la slide activa en 'time_s'."""
    # búsqueda lineal (puedes optimizar con bisect si quieres)
    for seg in intervals:
        if seg["end"] is None:  # último intervalo
            return seg["slide"]
        if seg["start"] <= time_s < seg["end"]:
            return seg["slide"]
    return None

from typing import List, Optional

def slides_in_interval(
    start: float,
    end: float,
    intervals: List[dict],
    *,
    min_fraction: float = 0.10,   # % mínimo del segmento que debe cubrir la slide
    min_seconds: float = 0.0,     # y/o segundos absolutos mínimos de cobertura
    slack: float = 0.25,          # margen (±s) para tolerar pequeñas imprecisiones
    sort_by_coverage: bool = True,
    top_k: Optional[int] = 1
) -> List[int]:
    """
    Devuelve las slides que realmente 'cuentan' en [start, end), filtrando
    las que cubren menos de min_fraction del segmento o menos de min_seconds.

    - 'slack' expande el segmento a [start-slack, end+slack] para evitar cortar
      por milésimas (timings manuales, FPS, etc.).
    - Si sort_by_coverage=True, ordena por mayor cobertura; si no, por aparición.
    - 'top_k' limita el nº de slides devueltas (tras el filtro).
    """
    seg_len = max(1e-6, end - start)  # evita división por cero
    seg_lo = start - slack
    seg_hi = end + slack

    cover_by_slide = {}   # slide_id -> (cover_seconds, first_order)

    order = 0
    for seg in intervals:
        slide = seg["slide"]
        if slide is None:
            continue

        s_lo = seg["start"]
        s_hi = float("inf") if seg["end"] is None else seg["end"]

        # intersección con margen
        lo = max(seg_lo, s_lo)
        hi = min(seg_hi, s_hi)
        overlap = max(0.0, hi - lo)
        if overlap <= 0:
            continue

        if slide not in cover_by_slide:
            cover_by_slide[slide] = [0.0, order]
            order += 1
        cover_by_slide[slide][0] += overlap

    # Filtro por cobertura
    out = []
    for slide, (cover_s, first_order) in cover_by_slide.items():
        frac = cover_s / seg_len
        if cover_s >= min_seconds or frac >= min_fraction:
            out.append((slide, cover_s, first_order))

    if not out:
        return []

    # Orden
    if sort_by_coverage:
        out.sort(key=lambda x: (-x[1], x[2]))   # más cobertura primero
    else:
        out.sort(key=lambda x: x[2])            # por aparición

    if top_k is not None:
        out = out[:top_k]

    return [slide for slide, _, _ in out]

# %%
from pathlib import Path
import datasets as ds


def build_dataset(folder="train", language="es", files=None,
                  dpi=150, target_size=(1600,900), mode="letterbox",
                  bg="white", store_slide_paths=False):
    rows = []
    files = get_files(folder) if files is None else files

    # Carga y parsea el maestro (una vez)
    blocks = parse_slide_blocks(f'{folder}.lst')

    for name in files:
        base = Path(f"/content/{folder}/{name}/manual_translations/{language}")
        with open(base / f"{name}.lst") as f:
            times = [(float(a), float(b)) for a,b in (ln.split() for ln in f.read().splitlines())]
        with open(base / f"{name}.en") as f:
            src = f.read().splitlines()
        with open(base / f"{name}.{language}") as f:
            tgt = f.read().splitlines()
        assert len(times) == len(src) == len(tgt)


        # 2) Audio (como ya hacías)
        wav_path = str(m4a_to_wav(f"/content/{folder}/{name}/{name}.m4a"))

        if str(name) in blocks:
            intervals = build_slide_intervals(blocks[str(name)])
        else:
            intervals = [{"start":0.0,"end":None,"slide":None}]
            print(f"[WARN] No hay bloque de slides para {name}")
        if str(name) in DESCRIPTIONS:
            desc = DESCRIPTIONS[str(name)]
        else:
            desc = None
            print(f"[WARN] No hay descripcion para {name}")


        # 3) Crea filas por segmento reusando las mismas referencias a slides
        for (s, e), txt_in, txt_out in zip(times, src, tgt):
            slides  = slides_in_interval(s, e, intervals)
            row = {
                "wav_path": wav_path,
                "start": s,
                "end": e,
                "source_text": txt_in,
                "target_text": txt_out,
                "slide_text": desc[slides[0]] if slides and desc else None ,

            }
            rows.append(row)

    return ds.Dataset.from_list(rows)

train_ds = build_dataset("dev", files=['500011', '624000', '609'])
val_ds   = build_dataset("dev", files=['550000','592'])
test_ds   = build_dataset("test")
# Out:
# ['404', '596001', '605000', '606', '545006']

# %%
print(train_ds)
print(val_ds)
print(test_ds)
# Out:
# Dataset({
#     features: ['wav_path', 'start', 'end', 'source_text', 'target_text', 'slide_text'],
#     num_rows: 708
# })
# Dataset({
#     features: ['wav_path', 'start', 'end', 'source_text', 'target_text', 'slide_text'],
#     num_rows: 742
# })
# Dataset({
#     features: ['wav_path', 'start', 'end', 'source_text', 'target_text', 'slide_text'],
#     num_rows: 1405
# })

# %%
def build_prompt_from_slide_texts(slide_text):
    """
    slide_texts: lista de strings (resúmenes de slide).
    """

    if slide_text:
        slide_text=slide_text.strip()

        if use_slide_context:
            content = (
                "<|audio_1|>\n"
                "You are a teaching assistant. Use the following SLIDE TEXT "
                "only as CONTEXT to disambiguate proper names, acronyms, and technical terms in the audio.\n"
                "PRIORITY: the spoken audio content.\n\n"
                "RULES:\n"
                "- Do not copy or paraphrase text from the context if it does not appear in the audio.\n"
                "- If there is a conflict, prioritize the audio.\n"
                "- Preserve numbers, units, symbols, and proper names.\n"
                "- If something is unintelligible, write [inaudible].\n"
                "[SLIDE-CONTEXT]\n"
                f"{slide_text}\n"
                "[/SLIDE-CONTEXT]\n\n"
                "Task: translate into Spanish (es-ES) only what is said in the audio.\n"
                "Output format: ONLY the translation, on a single line, with no labels or comments."
            )
        else:
            content = (
                "<|audio_1|>\n"
                "You are a teaching assistant.\n"
                "Task: translate into Spanish (es-ES) only what is said in the audio."
            )


    return processor.tokenizer.apply_chat_template(
        [{"role":"user","content": content}],
        tokenize=False, add_generation_prompt=True
    )

# %%
import torch, soundfile as sf
from PIL import Image

class CollatorPhi4Audio:
    def __init__(self, processor, answer_suffix="<|end|><|endoftext|>",
                 sr=16_000, ignore_idx=-100, cache=True,
                 force_image=True, dummy_size=(1600, 900), dummy_color="white"):
        self.proc = processor
        self.sr = sr
        self.pad_id = processor.tokenizer.pad_token_id
        self.suffix = answer_suffix
        self.ignore = ignore_idx
        self.cache_fd = {} if cache else None
        # imagen dummy para filas sin slide
        self.force_image = force_image
        self.dummy_image = Image.new("RGB", dummy_size, dummy_color)


    # No reabrir el WAV completo en cada segmento
    def _read_segment(self, path, start, end):
        if self.cache_fd is not None:
            if path not in self.cache_fd:
                self.cache_fd[path] = sf.SoundFile(path)
            f = self.cache_fd[path]
        else:
            f = sf.SoundFile(path)
        frames = int((end - start) * self.sr)
        f.seek(int(start * self.sr))
        audio = f.read(frames, dtype="float32")
        return audio


    def __call__(self, batch):
        prompts, answers, wavs = [], [], []

        for ex in batch:
            prompt = build_prompt_from_slide_texts(ex.get("slide_text"))
            prompts.append(prompt)
            answers.append(ex["target_text"] + self.suffix)

            wavs.append((self._read_segment(ex["wav_path"], ex["start"], ex["end"]), self.sr))


        # ---- Texto (prompt + respuesta) ---------------------------------
        tok_in  = self.proc.tokenizer(prompts,  return_tensors="pt", padding=True)
        tok_ans = self.proc.tokenizer(answers, return_tensors="pt", padding=True)

        input_ids = torch.cat([tok_in.input_ids, tok_ans.input_ids], dim=1)
        attn_mask = (input_ids != self.pad_id).long()

        labels = torch.full_like(input_ids, self.ignore)
        ans_len = tok_ans.input_ids.size(1)
        labels[:, -ans_len:] = tok_ans.input_ids

        # (Opcional) enmascarar CoT si lo usas en answers y supervise_cot=False
        # ... (puedes pegar aquí el bloque de máscara de CoT adaptado a tu formato)

        # ---- Embeddings multimodales (UNA sola llamada) -----------------
        kwargs = dict(text=prompts, audios=wavs, return_tensors="pt", padding=True)


        feats = self.proc(**kwargs)  # genera input_audio_embeds / input_image_embeds

        batch_out = {
            "input_ids":            input_ids,
            "labels":               labels,
            "attention_mask":       attn_mask,
            "input_audio_embeds":   feats["input_audio_embeds"],
            "audio_attention_mask": feats.get("audio_attention_mask"),
            "input_mode":           torch.ones(len(batch), dtype=torch.long) * 3 ,
        }
        return batch_out

# %%
train_dataloader = torch.utils.data.DataLoader(
    train_ds,
    shuffle=True,
    batch_size=4,
    collate_fn=CollatorPhi4Audio(processor),
    pin_memory=True,
)
val_dataloader = torch.utils.data.DataLoader(
    val_ds,
    shuffle=False,
    batch_size=4,
    collate_fn=CollatorPhi4Audio(processor),
    pin_memory=True,
)

# %% [markdown]
# ## 3  Entrenamiento

# %% [markdown]
# ### 3.1 Helpers

# %%
import math, os, gc, torch
from tqdm import tqdm
from typing import Dict, List, Tuple

def move_batch(batch, device):
    return {
        k: v.to(device, dtype=torch.bfloat16 if v.dtype == torch.float else torch.long)
        for k, v in batch.items()
    }

@torch.no_grad()
def avg_loss_on_loader(model, dataloader, device):
    model.eval()
    losses, n = 0.0, 0
    for batch in dataloader:
        batch = move_batch(batch, device)
        with torch.autocast(device_type="cuda", dtype=torch.bfloat16):
            out = model(**batch)
        losses += out.loss.item() * batch[list(batch.keys())[0]].size(0)
        n += batch[list(batch.keys())[0]].size(0)
    model.train()
    return losses / n

# %% [markdown]
# ### 3.2 Eval Definition

# %%
import soundfile as sf
from collections import defaultdict

_open_wavs = {}                  # caché: path → SoundFile

def read_segment(path, start, end, sr=16_000):
    """Lee [start,end] s de un WAV grande sin cargarlo entero."""
    if path not in _open_wavs:
        _open_wavs[path] = sf.SoundFile(path)
    f = _open_wavs[path]
    frames = int((end - start) * sr)
    f.seek(int(start * sr))
    return f.read(frames, dtype="float32")
def segments_by_audio(ds):
    groups = defaultdict(list)
    for ex in ds:
        groups[ex["wav_path"]].append(ex)
    # ordenamos cada audio por inicio temporal
    for segs in groups.values():
        segs.sort(key=lambda x: x["start"])
    return groups

# %%
val_groups  = segments_by_audio(val_ds)

# %%
from collections import defaultdict
from itertools import chain
import torch, gc
from tqdm import tqdm

device        = torch.device("cuda:0")
batch_size    = 6




def generate_output(groups):
    hyps_all, refs_all, srcs_all = [], [], []

    for wav_path, segs in tqdm(groups.items(), desc="Audios"):
        hyps, refs, srcs = [], [], []

        # dividimos en lotes (batch_size) para GPU
        for i in range(0, len(segs), batch_size):
            chunk = segs[i:i+batch_size]



            wavs   = [(read_segment(s["wav_path"], s["start"], s["end"]),16_000) for s in chunk]
            prompts= [build_prompt_from_slide_texts(s["slide_text"]) for s in chunk]


            inputs = processor(text=prompts, audios=wavs,
                               return_tensors="pt", padding=True
                               ).to(device)

            with torch.inference_mode(), torch.autocast("cuda"):
                gen_ids = model.generate(**inputs, generation_config=generation_config, max_new_tokens=1000, num_logits_to_keep=0)

            # quitamos el prompt textual
            gen_ids = gen_ids[:, inputs["input_ids"].shape[1]:]

            hyps.extend(
                processor.batch_decode(gen_ids.cpu(),
                                       skip_special_tokens=True,
                                       clean_up_tokenization_spaces=False)
            )

            # limpieza VRAM
            del inputs, gen_ids, prompts, wavs
            torch.cuda.empty_cache(); gc.collect()

            refs.extend([s["target_text"] for s in chunk])
            srcs.extend([s["source_text"] for s in chunk])

        print(hyps)
        print(refs)
        print(srcs)


        hyps_all.append(hyps)
        refs_all.append(refs)
        srcs_all.append(srcs)

    return hyps_all, refs_all, srcs_all

# %%
from __future__ import annotations

from itertools import chain
from typing import Callable, Dict, List, Tuple

import sacrebleu
from comet import download_model, load_from_checkpoint

# ────────────────────────────────────────────────────────────────────────────────
#  Cargamos (y cacheamos) el modelo COMET‑22 una sola vez
# ────────────────────────────────────────────────────────────────────────────────
_COMET_MODEL = None
_COMET_PATH = None
_MODEL_NAME = "Unbabel/wmt22-comet-da"


def _get_comet_model(gpus: int = 0):
    """Devuelve un modelo COMET‑22 listo para `predict` (cacheado)."""
    global _COMET_MODEL, _COMET_PATH

    if _COMET_MODEL is None:
        _COMET_PATH = download_model(_MODEL_NAME)  # se guarda en ~/.cache
        _COMET_MODEL = load_from_checkpoint(_COMET_PATH)

    # *Nota*: el parámetro `gpus` se pasa a `.predict` y **no** aquí, pero
    # exponemos el arg para quien quiera forzar CPU en la firma pública.
    return _COMET_MODEL


# ────────────────────────────────────────────────────────────────────────────────
#  Función principal
# ────────────────────────────────────────────────────────────────────────────────

def bleu_comet_by_audio(
    refs_audio: List[List[str]],
    hyps_audio: List[List[str]],
    srcs_audio: List[List[str]],
    transform: Callable[[str], str] = lambda x: x,
    comet_gpus: int = 0,
    comet_batch_size: int = 8,
) -> Tuple[Dict[str, float], List[Dict[str, float]]]:
    """Calcula BLEU y COMET‑22, **global** y **por audio**.

    Parameters
    ----------
    refs_audio, hyps_audio, srcs_audio : list[list[str]]
        Listas anidadas con el mismo nº de audios y segmentos.
    transform : callable
        Función de normalización por frase (identidad por defecto).
    comet_gpus : int
        Nº de GPUs a usar en `model.predict` (0 ⇒ CPU).
    comet_batch_size : int
        Tamaño de lote para COMET (trade‑off velocidad / memoria).

    Returns
    -------
    (global_metrics, per_audio_metrics)
        global_metrics    = {"bleu": float, "comet22": float}
        per_audio_metrics = [
            {"audio_id": i, "bleu": float, "comet22": float},
            ...
        ]
    """

    # ── Comprobaciones básicas ──────────────────────────────────────────────
    assert len(refs_audio) == len(hyps_audio) == len(srcs_audio), (
        "refs, hyps y srcs deben tener la misma longitud (nº audios)"
    )

    per_audio: List[Dict[str, float]] = []

    # ── Recorremos audio por audio ──────────────────────────────────────────
    comet_model = _get_comet_model(gpus=comet_gpus)

    for idx, (ref_seg, hyp_seg, src_seg) in enumerate(
        zip(refs_audio, hyps_audio, srcs_audio)
    ):
        assert len(ref_seg) == len(hyp_seg) == len(src_seg), (
            f"El audio {idx} contiene diferente nº de segmentos"
        )

        ref_seg = [transform(r) for r in ref_seg]
        hyp_seg = [transform(h) for h in hyp_seg]
        src_seg = [transform(s) for s in src_seg]

        # ── BLEU corpus‑level para el audio ────────────────────────────────
        bleu_score = sacrebleu.corpus_bleu(hyp_seg, [ref_seg]).score

        # ── COMET‑22 ───────────────────────────────────────────────────────
        samples = [  # una entrada por segmento
            {"src": s, "mt": h, "ref": r}
            for s, h, r in zip(src_seg, hyp_seg, ref_seg)
        ]
        comet_out = comet_model.predict(
            samples,
            batch_size=comet_batch_size,
            gpus=comet_gpus,
            progress_bar=False,
        )
        comet_score = comet_out["system_score"]  # media ya calculada

        per_audio.append(
            {
                "audio_id": idx,
                "bleu": bleu_score,
                "comet22": comet_score,
            }
        )

    # ── Métricas globales ──────────────────────────────────────────────────
    refs_all = list(chain.from_iterable(refs_audio))
    hyps_all = list(chain.from_iterable(hyps_audio))
    srcs_all = list(chain.from_iterable(srcs_audio))

    bleu_global = sacrebleu.corpus_bleu(hyps_all, [refs_all]).score

    comet_samples = [
        {"src": s, "mt": h, "ref": r}
        for s, h, r in zip(srcs_all, hyps_all, refs_all)
    ]
    comet_global = comet_model.predict(
        comet_samples,
        batch_size=comet_batch_size,
        gpus=comet_gpus,
        progress_bar=False,
    )["system_score"]

    return {"bleu": bleu_global, "comet22": comet_global}, per_audio

# %%
def eval_bleu_comet_fn_val(groups_val, processor, model, generation_config, device,
                           batch_size=8, transform=lambda x: x):
    # 1) Generar hipótesis
    hyps, refs, srcs = generate_output(groups_val)  # usa tu función tal cual

    # 2) Calcular métricas
    global_metrics, per_audio = bleu_comet_by_audio(
        refs_audio=refs,
        hyps_audio=hyps,
        srcs_audio=srcs,
        transform=transform,
        comet_gpus=1,        # o 0 si prefieres CPU
        comet_batch_size=8
    )
    return global_metrics, per_audio

# %% [markdown]
# ### 3.3 Train Val

# %%
def train(
    model,
    train_loader,
    val_loader,
    optimizer,
    device,
    acc_steps=2,
    max_epochs=5,
    clip_grad=1.0,
    scheduler=None,
    scheduler_type=None,
    ckpt_dir="checkpoints",
    patience=3,                       # early stopping
    eval_bleu_comet_fn=None,          # función que calcule métricas de traducción (ver sección 3)
    eval_bleu_args=None,              # dict opcional para pasar a esa función
    verbose_every=20
):
    os.makedirs(ckpt_dir, exist_ok=True)
    best_metric = -math.inf
    no_improve = 0

    model.to(device)
    model.train()
    optimizer.zero_grad(set_to_none=True)

    scaler = torch.cuda.amp.GradScaler(enabled=False)  # bfloat16 no necesita scaler; activarlo si usas fp16
    best_name=''
    for epoch in range(1, max_epochs+1):
        print(f"\nEpoch {epoch}/{max_epochs}")
        running = 0.0
        model.train()

        for step, batch in enumerate(tqdm(train_loader)):
            batch = move_batch(batch, device)

            with torch.autocast("cuda", dtype=torch.bfloat16):
                outputs = model(**batch)
                loss = outputs.loss / acc_steps

            loss.backward()

            running += loss.item() * acc_steps

            if (step + 1) % acc_steps == 0:
                torch.nn.utils.clip_grad_norm_(model.parameters(), clip_grad)
                optimizer.step()
                optimizer.zero_grad(set_to_none=True)

            if step % verbose_every == 0:
                print(f" step {step:<4} | loss = {loss.item() * acc_steps:.4f}")

        # ─── VALIDACIÓN ───────────────────────────────────────────
        model.eval()

        # Temporarily disable gradient checkpointing for evaluation
        for module in model.modules():
            if hasattr(module, 'gradient_checkpointing'):
                module.gradient_checkpointing = False

        val_loss = avg_loss_on_loader(model, val_loader, device)
        print(f"  -> val_loss: {val_loss:.4f}")

        # Métricas de traducción opcionales (BLEU/COMET)
        extra_metrics = {}
        if eval_bleu_comet_fn is not None:
            metrics_global, metrics_per_audio = eval_bleu_comet_fn(**(eval_bleu_args or {}))
            print(f"  -> BLEU: {metrics_global['bleu']:.2f} | COMET22: {metrics_global['comet22']:.3f}")
            extra_metrics = metrics_global
            current_key_metric = metrics_global["comet22"]  # decide cuál usar para “mejor modelo”
        else:
            current_key_metric = -val_loss  # si no hay métricas externas, usa la loss

        # Re-enable gradient checkpointing
        for module in model.modules():
            if hasattr(module, 'gradient_checkpointing') and eval_bleu_comet_fn is not None: # Only re-enable if it was originally True and we used the eval function
                 module.gradient_checkpointing = True


         # ---------- Scheduler step ----------
        if scheduler is not None:
            if scheduler_type == "plateau":
                scheduler.step(val_loss)               # en función de la loss
            else:
                scheduler.step()
        # ─── Checkpoint / Early stopping ─────────────────────────
        if current_key_metric > best_metric:
            best_metric = current_key_metric
            no_improve = 0
            path = os.path.join(ckpt_dir, f"best_epoch{epoch}.pt")
            torch.save({"model_state": model.state_dict(),
                        "optimizer_state": optimizer.state_dict(),
                        "epoch": epoch,
                        "val_loss": val_loss,
                        **extra_metrics}, path)
            best_name=path
            print(f"  ✔ Nuevo mejor modelo guardado en {path}")
        else:
            no_improve += 1
            print(f"  (sin mejora {no_improve}/{patience})")
            if no_improve >= patience:
                print("  ✖ Early stopping activado.")
                break

        # limpieza VRAM
        torch.cuda.empty_cache(); gc.collect()

    return best_name

# %%
from torch.optim.lr_scheduler import ReduceLROnPlateau
eval_args = dict(
    groups_val=val_groups,                # dict {wav_path: [segs...]}
    processor=processor,
    model=model,
    generation_config=generation_config,
    device=device,
    batch_size=8,
    transform=lambda x: x
)
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-5)


scheduler = ReduceLROnPlateau(optimizer, mode="min", factor=0.5, patience=1, min_lr=1e-7)

best_name=train(model, train_dataloader, val_dataloader, optimizer, device,
      scheduler=scheduler, scheduler_type="plateau",
      acc_steps=8, max_epochs=10, patience=3,)
      # eval_bleu_comet_fn=eval_bleu_comet_fn_val,
      # eval_bleu_args=eval_args)
# Out:
# /tmp/ipython-input-3027994405.py:26: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=False)  # bfloat16 no necesita scaler; activarlo si usas fp16
# Epoch 1/10
#   0%|          | 0/177 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torch/utils/checkpoint.py:85: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
#   1%|          | 1/177 [00:02<08:09,  2.78s/it]
#  step 0    | loss = 5.3796
#  12%|█▏        | 21/177 [00:14<01:31,  1.70it/s]
#  step 20   | loss = 2.1143
#  23%|██▎       | 41/177 [00:25<01:13,  1.86it/s]
#  step 40   | loss = 1.7890
#  34%|███▍      | 61/177 [00:37<01:09,  1.67it/s]
#  step 60   | loss = 2.6950
#  46%|████▌     | 81/177 [00:48<00:53,  1.78it/s]
#  step 80   | loss = 1.9491
#  57%|█████▋    | 101/177 [01:00<00:45,  1.66it/s]
#  step 100  | loss = 2.2675
#  68%|██████▊   | 121/177 [01:10<00:29,  1.89it/s]
#  step 120  | loss = 1.7925
#  80%|███████▉  | 141/177 [01:22<00:17,  2.05it/s]
#  step 140  | loss = 1.6450
#  91%|█████████ | 161/177 [01:33<00:07,  2.02it/s]
#  step 160  | loss = 1.4030
# 100%|██████████| 177/177 [01:41<00:00,  1.74it/s]
#   -> val_loss: 1.7821
#   ✔ Nuevo mejor modelo guardado en checkpoints/best_epoch1.pt
#
# Epoch 2/10
#   1%|          | 1/177 [00:00<01:39,  1.77it/s]
#  step 0    | loss = 1.6187
#  12%|█▏        | 21/177 [00:12<01:25,  1.83it/s]
#  step 20   | loss = 2.1845
#  23%|██▎       | 41/177 [00:24<01:22,  1.66it/s]
#  step 40   | loss = 1.9422
#  34%|███▍      | 61/177 [00:35<01:03,  1.83it/s]
#  step 60   | loss = 1.3762
#  46%|████▌     | 81/177 [00:46<00:49,  1.92it/s]
#  step 80   | loss = 1.6691
#  57%|█████▋    | 101/177 [00:58<00:42,  1.78it/s]
#  step 100  | loss = 2.0240
#  68%|██████▊   | 121/177 [01:09<00:30,  1.82it/s]
#  step 120  | loss = 1.1218
#  80%|███████▉  | 141/177 [01:20<00:20,  1.79it/s]
#  step 140  | loss = 1.5779
#  91%|█████████ | 161/177 [01:33<00:10,  1.51it/s]
#  step 160  | loss = 2.0111
# 100%|██████████| 177/177 [01:42<00:00,  1.73it/s]
#   -> val_loss: 1.7632
#   ✔ Nuevo mejor modelo guardado en checkpoints/best_epoch2.pt
#
# Epoch 3/10
#   1%|          | 1/177 [00:00<01:48,  1.62it/s]
#  step 0    | loss = 1.5931
#  12%|█▏        | 21/177 [00:13<01:34,  1.64it/s]
#  step 20   | loss = 1.3428
#  23%|██▎       | 41/177 [00:24<01:20,  1.70it/s]
#  step 40   | loss = 2.1619
#  34%|███▍      | 61/177 [00:36<01:02,  1.85it/s]
#  step 60   | loss = 1.3865
#  46%|████▌     | 81/177 [00:47<01:02,  1.54it/s]
#  step 80   | loss = 1.1457
#  57%|█████▋    | 101/177 [00:58<00:45,  1.66it/s]
#  step 100  | loss = 1.5167
#  68%|██████▊   | 121/177 [01:10<00:32,  1.71it/s]
#  step 120  | loss = 1.5925
#  80%|███████▉  | 141/177 [01:21<00:20,  1.73it/s]
#  step 140  | loss = 1.7889
#  91%|█████████ | 161/177 [01:33<00:09,  1.71it/s]
#  step 160  | loss = 1.0020
# 100%|██████████| 177/177 [01:41<00:00,  1.74it/s]
#   -> val_loss: 1.7826
#   (sin mejora 1/3)
#
# Epoch 4/10
#   1%|          | 1/177 [00:00<01:53,  1.55it/s]
#  step 0    | loss = 1.0713
#  12%|█▏        | 21/177 [00:12<01:24,  1.85it/s]
#  step 20   | loss = 1.2359
#  23%|██▎       | 41/177 [00:24<01:19,  1.72it/s]
#  step 40   | loss = 1.3799
#  34%|███▍      | 61/177 [00:35<01:02,  1.86it/s]
#  step 60   | loss = 1.2673
#  46%|████▌     | 81/177 [00:46<00:53,  1.78it/s]
#  step 80   | loss = 0.9972
#  57%|█████▋    | 101/177 [00:58<00:43,  1.77it/s]
#  step 100  | loss = 1.1156
#  68%|██████▊   | 121/177 [01:08<00:31,  1.76it/s]
#  step 120  | loss = 1.2043
#  80%|███████▉  | 141/177 [01:20<00:22,  1.61it/s]
#  step 140  | loss = 0.9833
#  91%|█████████ | 161/177 [01:32<00:10,  1.59it/s]
#  step 160  | loss = 1.0034
# 100%|██████████| 177/177 [01:41<00:00,  1.75it/s]
#   -> val_loss: 1.8383
#   (sin mejora 2/3)
#
# Epoch 5/10
#   1%|          | 1/177 [00:00<01:45,  1.67it/s]
#  step 0    | loss = 0.6049
#  12%|█▏        | 21/177 [00:12<01:34,  1.66it/s]
#  step 20   | loss = 0.8343
#  23%|██▎       | 41/177 [00:23<01:13,  1.86it/s]
#  step 40   | loss = 1.2153
#  34%|███▍      | 61/177 [00:34<01:03,  1.83it/s]
#  step 60   | loss = 1.1342
#  46%|████▌     | 81/177 [00:46<00:51,  1.85it/s]
#  step 80   | loss = 0.5954
#  57%|█████▋    | 101/177 [00:57<00:44,  1.72it/s]
#  step 100  | loss = 0.8716
#  68%|██████▊   | 121/177 [01:08<00:31,  1.78it/s]
#  step 120  | loss = 1.0835
#  80%|███████▉  | 141/177 [01:20<00:21,  1.70it/s]
#  step 140  | loss = 0.8937
#  91%|█████████ | 161/177 [01:31<00:09,  1.70it/s]
#  step 160  | loss = 1.2114
# 100%|██████████| 177/177 [01:41<00:00,  1.75it/s]
#   -> val_loss: 1.9572
#   (sin mejora 3/3)
#   ✖ Early stopping activado.

# %% [markdown]
# ## 4  Evaluación  (BLEU y COMET)

# %% [markdown]
# ### Evaluacion completa

# %%
torch.cuda.empty_cache(); gc.collect()


# Cargar checkpoint
ckpt = torch.load("checkpoints/best_epoch2.pt", map_location=device)
# ckpt = torch.load(best_name, map_location=device)
model.load_state_dict(ckpt["model_state"], strict=False)


model.gradient_checkpointing_disable()          # importante para evitar el bug/anular GC
model.eval()
model.config.use_cache = True                   # más memoria, pero más rápido

# %%
# Carga mejor checkpoint si quieres

groups  = segments_by_audio(test_ds)
print(f"{len(groups)=} audios")
hyps, refs, srcs = generate_output(groups)
# Out:
# len(groups)=5 audios
# Audios:   0%|          | 0/5 [00:00<?, ?it/s]/usr/local/lib/python3.12/dist-packages/torch/utils/checkpoint.py:85: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
# Audios:  20%|██        | 1/5 [03:38<14:34, 218.69s/it]
# ['Buenos días, al mediodía y por la noche.', 'Esta es la diapositiva titulada "e-sesion 404" que discute el impacto de la cirugía oncológica en los resultados.', 'La European School of Oncology invita a participar en su 404ª sesión.', 'La diapositiva discute el impacto de la cirugía oncológica en los resultados.', 'La diapositiva se titula "e-sesion 404" y discute el impacto de la cirugía oncológica en los resultados.', 'Al final de la presentación, al cerrar la ventana de transmisión web, se dirigirá a la evaluación de CME y el examen de opción múltiple.', 'La diapositiva se titula "e-sesion 404" y discute el impacto de la cirugía oncológica en los resultados.', 'La diapositiva se titula "e-sesion 404" y discute el impacto de la cirugía oncológica en los resultados.', 'La diapositiva se titula "e-sesion 404" y discute el impacto de la cirugía oncológica en los resultados.', 'La diapositiva se titula "e-sesion 404" y discute el impacto de la cirugía oncológica en los resultados.', 'La diapositiva se titula "e-sesion 404" y discute el impacto de la cirugía oncológica en los resultados.', 'La diapositiva se titula "e-sesion 404" y discute el impacto de la cirugía oncológica en los resultados.', 'Hola a todos.', 'Charles Balch de Houston, Texas, y yo estamos encantados de participar en esta sesión web para hablar sobre el impacto de los resultados quirúrgicos oncológicos. También estoy involucrado en esto mi buen amigo, el profesor Ricardo Adisicio, el ex presidente de la Sociedad Británica de Oncología Quirúrgica y el presidente electo de la Sociedad Europea de Oncología Quirúrgica, y él liderará un período de preguntas y respuestas al final de mi presentación.', 'La diapositiva se centra en el tema "THE IMPACT OF ONCOLOGICAL SURGERY ON THE OUTCOMES". El tema se presenta en un tono serio y profesional, con un fondo azul oscuro y texto en amarillo y blanco.', 'La diapositiva se titula "Global Surgery 2030: evidencia y soluciones para lograr salud, bienestar y desarrollo económico".', 'La primera es que el acceso a la atención quirúrgica es esencial para reducir la mortalidad y la morbidez de las condiciones quirúrgicas.', 'Así que el acceso universal a la atención quirúrgica segura y asequible es esencial.', 'La diapositiva se centra en la importancia de la cirugía en el tratamiento del cáncer, con un enfoque en la necesidad de mejorar la accesibilidad y la calidad de la cirugía en todo el mundo para el año 2030.', 'La diapositiva se centra en la importancia de la cirugía en el tratamiento del cáncer, con un enfoque en la necesidad de mejorar la accesibilidad y la calidad de la cirugía en todo el mundo para el año 2030.', 'La diapositiva se centra en "The Lancet Oncology Commission", discutiendo los problemas y soluciones relacionados con el acceso a la cirugía, la inversión en sistemas quirúrgicos públicos, la investigación y la educación en el campo de la oncología.', 'Y ofrecimos soluciones que incluyen un mejor sistema público regulado, especialmente en la formación y certificación de cirujanos, asociaciones internacionales, centralización de servicios quirúrgicos, ensayos clínicos novedosos y nuevas estrategias para mejorar la calidad y la escalabilidad de los sistemas quirúrgicos a través de la educación y la capacitación.', 'Y daré algunos ejemplos de eso más adelante en esta conferencia.', 'La Comisión de Oncología de Lantec discute la importancia de la especialización y la calidad en la cirugía de cáncer.', 'La Comisión de Oncología de Lantec discute la importancia de la especialización y la calidad en la cirugía de cáncer.', 'La diapositiva se centra en la "Comisión de Oncología de Lantec", que discute la importancia de la especialización y la calidad en la cirugía de cáncer.', 'Y aunque los países de alto ingreso, como muchos países de Europa y en los Estados Unidos, están impulsando una mayor especialización, globalmente hay una necesidad de cirujanos con una formación mucho más amplia.', 'La diapositiva presenta una  ...
# ['Buenos días, buenas tardes, buenas noches.', 'Les habla la presentadora de la conferencia.', 'La Escuela Europea de Oncología les da la bienvenida a su sesión virtual 404.', 'La sesión virtual de hoy está dedicada al impacto de la cirugía oncológica en los resultados.', 'Le recordamos que esta actividad está acreditada por el CME.', 'Al final de la presentación, al cerrar la ventana de retransmisión, se le redirigirá a la evaluación de CME y al test de opciones múltiples.', 'Se pedirá a los Mastermind competitors que empiecen el test una vez finalizada la evaluación.', 'Como recordatorio durante la sesión en directo, todos los participantes pueden formular preguntas en directo en cualquier momento, simplemente pulsando el botón correspondiente en la parte superior de la página.', 'Esto es un extracto de la política que se publica en nuestro sitio web en su totalidad.', 'Las preguntas serán recibidas por el profesor Riccardo Audisio del Western Hospital, Universidad de Liverpool, Prescott, Reino Unido, quien las comentará con el profesor Charles M. Balch del MD Anderson Cancer Center de la Universidad de Texas, Houston, Texas, EE. UU.', 'Ahora le concedemos la palabra al Profesor Balch.', 'Profesor, su micrófono está abierto.', 'Hola a todos.', 'Soy Charles Balch de Houston, Texas, y me complace unirme a este seminario web para hablar sobre el impacto de los resultados quirúrgicos oncológicos y también participo en esto con mi buen amigo el profesor Riccardo Audisio, ex presidente de la Sociedad Británica de Oncología Quirúrgica y el presidente electo de la Sociedad Europea de Oncología Quirúrgica y él moderará una ronda de preguntas y respuestas al final de mi presentación.', 'Así que voy a exponer brevemente mis diapositivas, pero espero que más adelante descarguen varios artículos que creo que son documentos fundamentales que involucran cirujanos de todo el mundo, y que provienen de la Comisión Lancet que se publicaron en 2015 en Lancet Oncology.', 'El primero de ellos fue sobre cirugía global en el año 2030 y voy a leer unas citas de estos artículos.', 'La primera es que el acceso a la atención quirúrgica es esencial para reducir la mortalidad y morbilidad por afecciones quirúrgicas, sin embargo y esto es realmente un hecho importante y alarmante.Más de 2000 millones de personas no tienen acceso a la cirugía y la anestesia y, además, esta cifra está probablemente subestimada.', 'Por lo tanto, el acceso universal a una atención quirúrgica segura y asequible es fundamental.', 'En un artículo posterior en el que participamos el Dr. Audisio y yo, en Lancet Oncology, nos centramos en la cirugía oncológica global y en cómo administrar una cirugía oncológica segura, asequible y oportuna y realmente yo recomendaría que todos los que nos están escuchando lo leyeran.', 'Bueno, este artículo fue publicado en Lancet Oncology en 2015 y como pueden ver en las flechas el Dr. Audisio y yo fuimos sus coautores y parte del resumen que voy a destacar muy brevemente indicaba que para el año 2030, para lo que solo faltan trece años, calculamos que serán necesarios 45 millones de procedimientos quirúrgicos en todo el mundo y sin embargo menos del 25% de los pacientes de cáncer en todo el mundo realmente consiguen una cirugía segura, asequible u oportuna.', 'Así que queda mucho trabajo por hacer a este respecto y citaré algunas cosas más de este artículo en Lancet Oncology; que los problemas del acceso a la cirugía, la escasez de inversión en sistemas quirúrgicos públicos, la baja inversión en investigación, en formación, en cirugía y las brechas en formación están notablemente extendidas en todo el mundo.', 'Y hemos ofrecido soluciones que incluyen, un sistema público mejor regulado, especialmente en la formación y la certificación de cirujanos, colaboraciones internacionales, súper centralización de los servicios quirúrgicos y, volveré a hablar de esto más tarde, nuevos ensayos clínicos quirúrgicos, y nuevos enfoques para mejorar la calidad y ...
# ['Good morning, afternoon and evening.', 'This is the conference operator.', 'The European School of Oncology welcomes you to their four hundred and forth e-session.', "Today's e-session is the impact of oncological surgery on the outcomes.", 'Please note that this activity is CME accredited.', 'At the end of the presentation by closing the webcast window you will be directed to the CME evaluation and multiple choice test.', 'Mastermind competitors will be prompted to start the quiz after having completed the evaluation.', 'As a reminder during the live session all participants can ask questions live at any time by simply pressing on the relevant button at the top of the page.', 'Here is an extract of the policy which is published on our website in full.', 'Questions will be received by Professor Riccardo Audisio of the Western Hospital University of Liverpool, Prescott, United Kingdom who will discuss them with Professor Charles M. Balch of the University of Texas MD Anderson Cancer center, Houston, Texas, USA.', 'We will now hand over to Professor Balch.', 'Professor, your line is now open.', 'Hello everyone.', "This is Charles Balch from Houston, Texas and I'm pleased to join this webinar to talk about the impact of oncologic surgical outcomes and I'm also involved in this is my good friend Professor Riccardo Audisio, the past president of the British Society of Surgical Oncology and the president elect of the European Society of Surgical Oncology and he will lead a question and answer period at the end of my presentation.", "So I'll go briefly through my slides but I'm hoping that you will download at a future time several papers that I think are seminal papers involving surgeons around the world, and these come from the Lancet Commission that were published in 2015 in Lancet Oncology.", "The first of which was about global surgery in the year 2030 and I'll just give a few quotes from these papers.", 'The first is access to surgical care is essential for reduction of mortality and morbidity from surgical conditions, however and this is really an important fact and a startling one. More than two billion people have no access to surgery and anesthesia and moreover this figure is probably an underestimate.', 'So universal access to safe, affordable, surgical care is essential.', 'In a subsequent paper that Dr Audisio and I were involved in, in Lancet Oncology focused on global cancer surgery and how to deliver safe, affordable and timely cancer surgery and I would really commend this paper for all of you who are listening to read.', "So this paper was published in Lancet Oncology in 2015 and as you can see from the arrows after Audisio and I were both co-authors of this and part of the summary which I will highlight very briefly stated that by the year 2030, that's just thirteen years from now, we estimate that forty five million surgical procedures will be needed worldwide and yet less than twenty five percent of cancer patients worldwide actually get safe affordable or timely surgery.", "So there's much work to be done here and just a few more quotes from this paper in Lancet Oncology that issues of access to surgery, a paucity of investment in public surgical systems, low investment in research, in training, in surgery and educational gaps are remarkably widespread globally.", "And we offered up solutions that include, a better regulated public system especially in the training and certification of surgeons, international partnerships, super centralization of surgical services and I'll come back to that later, novel surgical clinical trials, and new approaches to improve quality and scale-up of cancer surgical systems through education and training.", "And I'll give some examples of that later in this lecture.", 'So going on with a few more summary statements from this important paper, achieving good outcomes in modern cancer surgery is technically demanding and it is recognized that outcomes improve when such surgery is u ...
# Audios:  40%|████      | 2/5 [11:18<18:02, 360.73s/it]
# ['Hola a todos.', 'Es un placer estar aquí y compartir con ustedes mi experiencia en la evaluación de planes de tratamiento en radioterapia.', 'Soy Nuria Jornet, soy consultora médica física y cabeza del departamento de física de radioterapia en el Hospital de la Santa Creu i Sant Pau, Barcelona.', 'Los objetivos de aprendizaje de esta sesión de e-SESessions son los siguientes: 1) Proporcionar una visión general del proceso de tratamiento de la radioterapia; 2) Analizar diferentes aspectos de la "calidad del plan de tratamiento"; 3) Evaluar la calidad del plan de tratamiento; 4) Diseñar orientación radiológica para ensayos clínicos y protocolos de tratamiento internos.', 'Objetivos de aprendizaje para una sesión de e-SESessions.', 'Y también porque es muy importante si tienes que diseñar orientación radiológica para ensayos clínicos y protocolos de tratamiento internos.', 'El proceso de tratamiento de radioterapia para pacientes, que incluye la prescripción, la planificación, la imagen y la delineación del contorno, la entrega y la verificación de la entrega del tratamiento, es crucial.', 'Un paciente llega a nuestro departamento y el radiólogo decide si se le prescribirá el tratamiento.', 'La diapositiva trata sobre el proceso de tratamiento de radioterapia para pacientes, incluyendo los pasos desde la prescripción del tratamiento hasta su entrega.', 'Y de esas imágenes, los radiólogos oncológicos delinearán los volúmenes que quieren tratar y los volúmenes que quieren proteger.', 'La diapositiva trata sobre el proceso de tratamiento de radioterapia para pacientes, incluyendo los pasos desde la prescripción del tratamiento hasta su entrega.', 'La diapositiva trata sobre el proceso de tratamiento de radioterapia para pacientes, incluyendo los pasos desde la prescripción del tratamiento hasta su entrega.', 'La diapositiva trata sobre el proceso de tratamiento de radioterapia para pacientes, incluyendo los pasos desde la prescripción del tratamiento hasta su entrega.', 'El paciente llegará en diferentes días al departamento de radioterapia para recibir el tratamiento, que se realizará en la unidad de radioterapia.', 'La diapositiva trata sobre el proceso de tratamiento de radioterapia para pacientes, incluyendo los pasos desde la prescripción del tratamiento hasta su entrega.', 'Así que detrás de escena para que esto suceda, para que obtengamos un tratamiento que sea el que prescribió el oncólogo radiante, estamos haciendo, los físicos, básicamente haciendo una máquina de rayos X para garantizar que todo esté funcionando bien.', 'Estamos realizando también un sistema de planificación de tratamiento, Q8.', 'La diapositiva se titula "Behind the scenes" y discute el proceso de calidad y control de la máquina (Machine QA) y el tratamiento (Treatment delivery) en un entorno de salud.', 'Y esta parte aquí, incluso si tenemos esto bajo control, sabemos que el paciente también puede cambiar durante el tratamiento, por ejemplo, o que la máquina, el día del tratamiento, puede no estar funcionando como cuando hacemos nuestra prueba de calidad.', 'La "Plan Calidad" se refiere a la adecuación clínica de la distribución de la dosis de tratamiento que se puede esperar en realidad.', 'La "Plan Calidad" se refiere a la adecuación clínica de la distribución de la dosis de tratamiento que se puede esperar en realidad.', 'La diapositiva se centra en la "Plan Calidad" en el contexto de la oncología, específicamente en la evaluación de la dosis de tratamiento en la radioterapia.', 'Y luego realizaremos una evaluación de la dosis de tratamiento entregada, teniendo en cuenta la prescripción y el volumen que el paciente ha indicado.', 'La diapositiva se centra en la "Plan Calidad" en el contexto de la oncología, específicamente en la evaluación de la dosis de tratamiento en la radioterapia.', 'Los componentes y procesos involucrados en la determinación de las dosis de tratamiento en la radioterapia.', 'La diapositiva trata sobre los componentes y proceso ...
# ['Hola a todos.', 'Es un placer estar aquí, y haber sido invitada por el profesor Franco, para compartir con ustedes mi experiencia en la evaluación de los planes de tratamiento en radioterapia.', 'Soy Nuria Jornet, soy Física Médica Consultora, Jefe Clínica de Física Radioterápica, en el Hospital de la Santa Creu i Sant Pau, de Barcelona.', 'Y bien, los objetivos de aprendizaje de esta ponencia serán proporcionarles una visión general del proceso de tratamiento con radioterapia.', 'Analizaremos los diferentes ángulos de la calidad del plan de tratamiento, porque al final de esta sesión, me gustaría que pudieran hacer una evaluación crítica de la calidad del plan siempre que se enfrenten a un plan de tratamiento elaborado por el físico médico.', 'Y también, porque es muy importante si tienes que diseñar pautas de radioterapia para ensayos clínicos, y también para protocolos internos de tratamiento.', 'Entonces, ¿qué implica el tratamiento de radioterapia?', 'Básicamente, vamos a tener un paciente en nuestro departamento, y el radiooncólogo decidirá si se va a tratar, y en este caso, él prescribirá el tratamiento.', 'Luego se someterá a algunas pruebas de diagnóstico por la imagen, por lo general mediante TAC.', 'Y de esas imágenes el radiooncólogo delineará los volúmenes que quieren tratar y los volúmenes que quieren proteger.', 'Toda esta información irá al departamento de física, que trabajarán en sus ordenadores para elaborar un plan de tratamiento, para conseguir la prescripción de tratamiento del radiooncólogo.', 'Y aquí realizaremos la mayor parte de nuestra evaluación del plan.', 'No obstante, sabemos que este plan se administrará al paciente en diferentes fracciones.', 'El paciente acudirá, en distintos días, al tratamiento, al departamento de radioterapia, irá a la unidad de tratamiento, y nosotros le administraremos el tratamiento.', 'Entonces, lo que deberíamos preguntarnos es si este tratamiento que se está administrando, concuerda con el tratamiento que estaba planeado, y por lo tanto con la prescripción de tratamiento del radiooncólogo.', 'Así que, tras las bambalinas para que esto suceda, para que podamos tener un tratamiento, que es el que el radiooncólogo prescribió, nosotros estamos haciendo, los físicos, básicamente estamos haciendo control de calidad de las máquinas para garantizar que todo funciona bien.', 'También estamos haciendo control de calidad del sistema de planificación del tratamiento; tenemos una prueba estándar para eso.', 'Pero luego tenemos al paciente, las imágenes, la planificación del tratamiento.', 'Y esta parte de aquí, incluso si tenemos esto bajo control, sabemos que el paciente también puede cambiar algo en el tratamiento, por ejemplo, o que la máquina, el día del tratamiento, puede no estar funcionando tan bien con nuestras pruebas de control de calidad.', 'Entonces, ¿qué es la calidad del plan?', 'De hecho, la calidad del plan es la adecuación clínica de la distribución de la dosis administrada que se puede esperar de manera realista de un plan de tratamiento.', 'Entonces, calcularemos la dosis en las imágenes del paciente.', 'Y luego tendremos una evaluación de la dosis administrada, teniendo en cuenta la prescripción, y también el volumen que ha sido delineado por el paciente.', 'He dicho aquí «esperada de manera realista», y es básicamente porque, tenemos que tener en cuenta las incertidumbres a las que nos enfrentamos cuando calculamos la distribución de la dosis, pero también cuando administramos la distribución de la dosis a un paciente en particular, diferentes fracciones.', 'Entonces, ¿cuáles son las aportaciones de las que proceden estas incertidumbres?', 'Básicamente, tenemos diferentes aportaciones, tenemos aportaciones que pertenecen al propio sistema de planificación de tratamientos.', 'Tenemos lo que llamamos el modelo de Haz.', 'Además, tenemos cómo se calcula esta dosis dentro del paciente de tratamiento.', 'También tenemos el modelo de Paciente.', 'Por lo tanto, sup ...
# ['Hello everybody.', "So, it's a pleasure to be here, and to have been invited by Professor Franco, to share with you my experience on the evaluation of treatment plans in radiation therapy.", 'I am Nuria Jornet, I am Consultant Medical Physicist, Clinical Head for Radiotherapy Physics, in the Hospital of la Santa Creu i Sant Pau, in Barcelona.', 'So, the learning objectives of this lecture will be to give you an overview of the radiation therapy treatment process.', 'We will analyse the different angles of treatment plan quality, because at the end of this session, I would like you to have a critical assessment of plan quality whenever you are facing a treatment plan produced by the medical physicist.', "And also, because it's very important if you have to design radiotherapy guidance for clinical trials, and also for internal treatment protocols.", 'So, radiation therapy treatment, what does it involve?', "Basically, we'll have a patient come into our department, and the radiation oncologist will decide whether to treat, and in this case, he will prescribe the treatment.", 'Then he will go under some imaging, usually using CT.', 'And from those images the radiation oncologist will delineate the volumes that they want to treat and the volumes they want to protect.', 'All this information will go to the physics department, that they will work on their computers to produce a treatment plan, achieving the treatment prescription of the radiation oncologist.', 'And here we will perform most of our plan evaluation.', 'However, we know that this plan will be delivered to the patient in different fractions.', 'The patient will come, different days, to the treatment, to the radiation therapy department, go into the treatment unit, and we will deliver the treatment.', 'So, the thing that we should ask ourselves is whether this treatment that is being delivered, agrees with the treatment that was planned, and therefore with the treatment prescription by the radiation oncologist.', 'So, behind the scenes to make this happen, so that we get a treatment, that is the one that the radiation oncologist prescribed, we are doing, the physicists, we are basically doing machine QA to guarantee that everything is working fine.', 'We are doing also Treatment Planning System QA; we have a standard test for that.', 'But then we have the patient, the imaging, treatment planning.', 'And this part here, even if we have this under control, we know that the patient also may change something in the treatment, for instance, or that the machine, the day of the treatment, may not be performing as well with our QA tests.', 'So, what is plan quality?', 'In fact, plan quality is the clinical suitability of the delivered dose distribution that can be realistically expected from a treatment plan.', 'So, we will calculate the dose on the images of the patient.', 'And then we will have an assessment of the delivered dose, taking into account the prescription, and also the volume that had been delineated by the patient.', 'I have put here " realistically expected", and it\'s basically because, we have to take into account the uncertainties that we are facing when we are calculating the dose distribution, but also delivering the dose distribution to a particular patient, different fractions.', 'So, what are the inputs where these uncertainties come from?', 'So basically, we have different inputs, we have inputs which belong to the treatment planning system itself.', 'We have what we call the Beam model.', 'Also, we have how this dose is calculated inside the treatment patient.', 'We also then, we have the Patient model.', 'So, we assume that the patient, when we have the CT images and we know the densities, and we will use this combined with this to get the final dose distribution.', 'And then we have the Treatment Plan.', 'So, this will give us the dose distribution as is evaluated and approved by the radiation oncologist.', 'On the other side, we have the treatment. ...
# Audios:  60%|██████    | 3/5 [19:54<14:22, 431.33s/it]
# ['La diapositiva se centra en temas relacionados con el cáncer de mama avanzado y su impacto en la vida nocturna.', 'Es un placer hablar con usted hoy.', 'Y espero que tengamos algunas preguntas interesantes que surjan también.', 'Las cosas sobre el cáncer de mama avanzado que nos preocupan por la noche.', 'De acuerdo, genial.', 'Así que nuestro tema de hoy son las cosas sobre el cáncer de mama avanzado que nos mantienen despiertos por las noches.', 'De hecho, hay muchos temas diferentes que podríamos discutir aquí, porque estaba pensando en ello mientras terminaba mis diapositivas y pensando que hay tantas cosas que nos mantienen despiertos, cuidando a nuestros pacientes.', 'Las cosas sobre el cáncer de mama avanzado que nos preocupan por la noche', 'La diapositiva se centra en el tema de "Things about advanced breast cancer that keep us up at night", presentada por Hope S Rugo, MD, quien es un profesor de medicina y director de la educación en oncología y ensayos clínicos en la Universidad de California, San Francisco Medical Center.', 'De acuerdo, vamos a discutir varios temas relacionados con el tratamiento de la enfermedad de Hodgkin (ABC).', 'La diapositiva se titula "Algunas cosas sobre ABC que nos mantienen despiertos por la noche" y discute varios temas relacionados con el tratamiento de la enfermedad de Hodgkin (ABC).', 'Trata el cáncer de mama triple negativo metastásico.', 'La diapositiva se titula "Algunas cosas sobre ABC que nos mantienen despiertos por la noche" y discute varios temas relacionados con el tratamiento de la enfermedad de Hodgkin (ABC).', '¿Por qué tan pocos se benefician de este tratamiento y si podríamos extender la inmunoterapia al cáncer de mama metastásico más común, el receptor positivo de la hormona del crecimiento?', 'Antibiótico-drug conjugates are a very exciting new way to deliver chemotherapy that seems to be more effective with reduced toxicity.', 'Un comunicado de prensa emocionante hoy.', 'Las metástasis cerebrales continúan siendo un gran tema para nosotros en términos de desafíos y manejo.', '"Y luego la terapia de secuenciación."', '[La diapositiva se titula "Algunas cosas sobre ABC que nos mantienen despiertos por la noche" y discute varios temas relacionados con el tratamiento de la enfermedad de Hodgkin (ABC).]', '"Y como se estudian nuevos agentes, siempre tenemos que descubrir cómo encajar esos nuevos agentes, cómo tratar mejor a nuestros pacientes."', 'Y, incluso si tienes un buen diagrama sobre cómo tratar a un paciente, tenemos que individualizar la terapia para el paciente.', 'Hay situaciones que no encajan en nuestras guías o diagramas, y es necesario considerar al paciente individual y su cáncer.', '"Por ejemplo, creo que una de las áreas más importantes para nosotros son los pacientes que tienen enfermedad de receptor de hormonas positivo, donde realmente estamos luchando con cuándo abandonar el tratamiento con hormonas."', '"Ahora tenemos varias opciones diferentes y los pacientes que tienen resistencia inicial a la terapia endocrina pueden ser un área muy difícil para nosotros determinar."', 'La diapositiva se titula "Algunas cosas sobre ABC que nos mantienen despiertos por la noche" y discute varios temas relacionados con el tratamiento de la enfermedad de Hodgkin (ABC).', 'Tenemos diferentes problemas en los Estados Unidos que en otros países del mundo, con diversas aseguradoras y Medicare.', 'Pero para todas las personas en el mundo, el aumento del costo de la atención por cáncer es un gran tema, incluso cómo manejar la vida cuando se necesita venir para citas, sin siquiera considerar el costo de los medicamentos y la propia parte de costo.', 'Otras cuestiones para debatir que no tenemos tiempo para.', 'La diapositiva se titula "Algunas cosas sobre ABC que nos mantienen despiertos por la noche" y discute varios temas relacionados con el tratamiento de la enfermedad de Hodgkin (ABC).', '¿Cuándo podemos detener los anticuerpos en pacientes con enfermedad de Hodgkin  ...
# ['Muchas gracias.', 'Es un placer hablar con ustedes hoy.', 'Y esperemos que surjan también preguntas interesantes.', 'Déjenme solo, voy a compartir mis diapositivas y ponerlas.', 'Muy bien, perfecto.', 'Y bien, el tema de hoy es «Aspectos del cáncer de mama avanzado que nos quitan el sueño».', 'Y, de hecho, aquí podríamos comentar muchos temas distintos porque estaba pensando en ello mientras terminaba mis diapositivas y pensando que hay muchísimas cosas que pueden quitarnos el sueño en el cuidado de nuestras pacientes, pero nos vamos a centrar en unas cuantas.', 'Y también podremos hablar sobre otras que surjan.', 'Aquí tienen información sobre mí.', 'Bien, ¿de qué vamos a hablar?', 'Acerca del cáncer de mama avanzado.', 'Es decir, una de las cosas es sin duda el tratamiento del cáncer de mama triple negativo.', 'Hablaremos de inmunoterapia, toxicidad.', 'Por qué tan pocas se benefician de este tratamiento y si podríamos o no ampliar la inmunoterapia al subgrupo más frecuente de cáncer de mama metastásico, la enfermedad con positividad para receptores hormonales.', 'Los conjugados de anticuerpo y fármaco son una nueva forma muy interesante de administrar quimioterapia que parece ser más eficaz con una menor toxicidad.', 'Hay un interesante comunicado de prensa hoy, lo compartiré con ustedes.', 'Las metástasis cerebrales siguen siendo un tema fundamental para nosotros en términos de dificultades y manejo.', 'Y luego, la secuenciación de la terapia.', 'Les mostraré algunos ejemplos de secuenciación, pero sigue siendo un reto.', 'Y cuando se estudian nuevos agentes tenemos siempre que averiguar cómo encajar esos agentes, cómo tratar mejor a nuestras pacientes.', 'E incluso si tienes un buen diagrama de flujo sobre cómo tratar a una paciente, tenemos que individualizar la terapia para la paciente.', 'Por lo tanto, puede haber situaciones que no encajen en nada de lo que vemos en nuestros diagramas de flujo o directrices y realmente solo hay que tener en cuenta a la paciente individual y su cáncer.', 'Por ejemplo, creo que una de las áreas más amplias para nosotros son las pacientes que tienen enfermedad con positividad para receptores hormonales; en estos casos no sabemos muy bien cuándo abandonar el tratamiento endocrino.', 'Ahora tenemos una serie de opciones diferentes y determinar qué pacientes tienen una resistencia inicial a la terapia endocrina puede ser una cuestión muy difícil para nosotros.', 'Por supuesto, la toxicidad económica es un problema para nuestras pacientes en todo el mundo.', 'En los Estados Unidos tenemos problemas distintos a los de otros países del mundo con diferentes seguros y Medicare.', 'Pero para todo el mundo, el aumento del costo de la atención oncológica es un tema importante que incluye incluso cómo organizar tu vida cuando tienes que acudir a las citas, sin siquiera considerar el costo de los medicamentos y la parte que te corresponde de ese costo.', 'Otros temas de debate para los que no tenemos tiempo.', 'Mencioné la enfermedad con positividad para receptores hormonales de progresión rápida.', '¿Cuándo podemos detener los anticuerpos en pacientes con enfermedad HER2+ que parecían no tener la enfermedad o que no presentaban indicios de enfermedad durante mucho tiempo?', '¿Basta con 5 años?', '¿Deberíamos continuar durante 10 años?', 'Este es un problema enorme en países donde los fármacos solo están aprobados durante la combinación con quimioterapia.', 'Y también, es un problema para todos nosotros porque queremos que este pequeño grupo de pacientes sean nuestras pacientes que se curan de la enfermedad.', 'Y entonces la pregunta sobre cuándo podemos realmente... ¿funcionará también reiniciar la terapia si el cáncer vuelve a crecer? Esta es una gran pregunta.', 'Lo mismo ocurre con la inmunoterapia.', 'La duración del tratamiento.', 'Y luego, el tratamiento de la ascitis resistente es un gran problema para nuestras pacientes.', 'El cáncer lobulillar suele ser un área donde realmente tenemos pro ...
# ['Thank you very much.', "It's a pleasure to talk to you today.", "And hopefully, we'll have some interesting questions that come up as well.", "Let me just, I'm gonna share my slides and put them on.", 'Okay, great.', 'So, our topic today is " Things about advanced breast cancer that keep us awake at night."', "And indeed, there are many different topics that we could discuss here because I was thinking about it as I was finishing up my slides and thinking that there are so many things that can keep us awake taking care of our patients, but we're gonna focus on just a few of them.", 'And also, we can talk about any others that come up.', 'Okay, my disclosures here.', 'Okay, so, what are we gonna talk about?', 'About advanced breast cancer.', 'So, treating metastatic triple-negative breast cancer is certainly one.', "We'll talk about immunotherapy, toxicity.", 'Why do so few benefit from this treatment and whether or not we could extend immunotherapy to the most common subset of metastatic breast cancer, hormone receptor-positive disease.', 'Antibody drug conjugates are a very exciting new way to deliver chemotherapy that seems to be more effective with reduced toxicity.', "An exciting press release today, I'll share with you.", 'Brain metastases continue to be a big topic for us in terms of challenges and management.', 'And then, sequencing therapy.', "I'll show you some examples of sequencing, but it continues to be a challenge.", 'And as new agents are being studied, we always have to figure out how to fit in those agents, how best to treat our patients.', 'And even if you have a nice flow chart about how to treat a patient, we have to individualise the therapy for the patient.', "So, there may be situations that don't quite fit into anything that we see in our flow charts or guidelines and you really just have to take the individual patient and their cancer into account.", "For example, I think one of the biggest areas for us are patients who have hormone receptor-positive disease where we're really struggling with when to abandon endocrine therapy.", 'We now have a number of different options and patients who have upfront resistance to endocrine therapy can be a very difficult area for us to determine.', 'Of course, financial toxicity is an issue for our patients worldwide.', 'We have different issues in the United States than other countries of the world with various insurance and Medicare.', "But for all people in the world, the increase in cost of cancer care is a big topic including just even how to manage your life when you're needing to come in for appointments without even considering the cost of drugs and your own share of cost.", "Other topics for discussion that we don't have time for.", 'I mentioned the rapidly progressive hormone receptor-positive disease.', 'When can we stop antibodies in patients with HER2-positive disease who seemed to be without disease or NED for a long time?', 'Is 5 years enough?', 'Should we continue for 10 years?', 'This is a huge problem in countries where the drugs are only approved during the combination with chemotherapy.', 'And also, an issue for all of us because we want to have this tiny group of patients be our patients who are cured of disease.', 'And then the question about when we can actually... will it work as well to restart therapy if the cancer grows again, is a big question.', 'The same is true for immunotherapy.', 'The duration of treatment.', 'And then, management of refractory ascites is a big issue for our patients.', 'Lobular cancer tends to be an area where we really have trouble managing the cancer and lobular cancer over the spectrum of disease is an increasing issue that thankfully has achieved some recognition.', 'And then, patients who have chest-wall disease that can be incredibly difficult to manage.', "Again, I chose not to discuss those because we don't have specific data with which to support decision-making.", 'Hopefully, we will in the future.', "So,  ...
# Audios:  80%|████████  | 4/5 [27:48<07:28, 448.37s/it]
# ['Hola a todos.', 'Mi nombre es Ramón de Mello y estoy muy contento de coordinar esta sesión multidisciplinaria sobre cáncer rectal.', 'Hoy tenemos aquí expertos de todo el mundo que discutirán la multidisciplinariedad, cómo podemos abordar mejor el cáncer de recto para mejorar los resultados.', 'Y tenemos dos expertos que darán su presentación, un oncólogo médico Dr. Katia Pérez y un oncólogo radiactivo Prof. María Antonieta Gamboa Cortana.', 'La diapositiva se titula "Multidisciplinaria sesión on rectal cancer", lo que indica que el tema de la sesión es un enfoque multidisciplinario sobre el cáncer rectal.', 'Y al final, estamos abiertos a preguntas y a discutir lo que creemos que es pertinente para esta sección.', 'La sesión multidisciplinaria sobre cáncer rectal incluye a tres expertos y dos participantes en la discusión.', 'Buenas tardes y es un placer estar aquí hoy.', 'Mi nombre es Katia Roque Pérez y voy a presentar una revisión de la gestión multidisciplinaria en el tratamiento del cáncer de recto.', 'Antes de 2020, hay dos tratamientos estándar diferentes para el cáncer de recto avanzado localmente: un corto curso de radioterapia o un largo curso de quimioterapia seguida de cirugía de recto y quimioterapia adjuvante para pacientes con factores de riesgo.', 'El enfoque multimodal ha mejorado las tasas de localización, pero no ha tenido un impacto significativo en las tasas de recurrencia distante o en la supervivencia general.', 'La diapositiva presenta una comparación entre dos estudios, Bujko et al. y Ngan SY et al., en relación con la eficacia de la cirugía de conservación de la recta (SCRT) frente a la cirugía de reconstrucción de la recta (LCRT).', 'La primera pregunta es: ¿Cuál es el régimen óptimo para la radioterapia de nodules? ¿El curso corto o el curso largo?', 'En Polonia, el curso corto de radioterapia seguido de cirugía dentro de siete días se compara con el curso largo de quimioterapia seguida de cirugía en cuatro a seis semanas.', 'La sobre supervivencia, la supervivencia libre de enfermedad y la recurrencia local a 4 años fueron similares entre los dos grupos.', 'Sin embargo, los pacientes que recibieron el curso largo tuvieron una mayor respuesta completa de patología, con un 16% frente a un 0,7%', '"También, el grupo de oncología de radiación transdorsal compara la radioterapia corta preoperatoria con la radioterapia larga preoperatoria en pacientes con tumores de la recta."', 'No hay diferencia significativa en los resultados oncológicos, pero los pacientes con un corto curso de radioterapia tienen una mayor tasa de recurrencia local y una menor tasa de respuesta completa.', 'En este punto, tenemos una pregunta más.', 'La supervivencia sin enfermedad durante un período de 5 años es significativamente mayor en pacientes con pCR en comparación con aquellos sin pCR.', 'La diapositiva se centra en la importancia del pCR (patiendo a la Curación Completa) en el tratamiento de pacientes con cáncer de recto. Presenta un análisis de 27 artículos basados en 17 diferentes conjuntos de datos, enfocándose en la supervivencia sin enfermedad durante un período de 5 años.', 'La supervivencia sin enfermedad durante 5 años fue del 83% para pacientes con pCR y del 65% para otros.', 'La diapositiva se centra en la importancia del pCR (patiendo a la Curación Completa) en el tratamiento de pacientes con cáncer de recta. Presenta un análisis de 27 artículos basados en 17 diferentes conjuntos de datos, enfocándose en la supervivencia sin enfermedad durante un período de 5 años.', 'La Curación Completa (pCR) es un factor pronóstico favorable en pacientes con cáncer de recto.', 'Pero, ¿qué sucede si retrasamos la cirugía?', 'La diapositiva discute el estudio "SRT y cirugía retrasada: Stockholm III", que compara los resultados de la cirugía inmediata con la cirugía retrasada en pacientes con cáncer de estómago.', 'Un grupo de 140 pacientes con cáncer de recto resectable se dividió en tres grupos.', '"Curso corto de quimioter ...
# ['Hola a todos.', 'Soy Ramón de Mello y estoy encantado de coordinar esta sesión multidisciplinaria sobre el cáncer rectal.', 'Hoy tenemos aquí expertos de todo el mundo que hablarán sobre multidisciplinariedad, ¿cómo podemos abordar mejor el cáncer rectal para mejorar los resultados?', 'Y tenemos dos expertas que harán una presentación, una oncóloga médica, la Dra. Katia Pérez, y una radiooncóloga, la profesora Maria Antonietta Gambacorta.', 'Así que empezaremos con la Dra. Katia Pérez, que nos dará una visión del oncólogo médico en el cáncer rectal y después, terminaremos con la profesora Gambacorta, que nos dará una visión del radiooncólogo en el tratamiento del cáncer rectal.', 'Y al final, estaremos abiertos a preguntas y a comentar lo consideren pertinente para esta sección.', 'Katia, por favor, adelante.', 'DRA. Buenas tardes, es un placer estar aquí hoy.', 'Y mi nombre es Katia Roque Pérez, y voy a presentar una revisión del manejo multidisciplinario del cáncer rectal.', 'Antes de 2020, existen dos tratamientos estándar diferentes para el cáncer rectal localmente avanzado, un ciclo corto de radioterapia o un ciclo largo de radioquimioterapia, seguidos de cirugía con EMT y quimioterapia adyuvante para pacientes con factores de riesgo.', 'Si bien este enfoque multimodal ha mejorado las tasas de recurrencia local, no ha tenido efectos significativos en las tasas de recurrencia a distancia o la supervivencia global.', 'Así es como surgen preguntas importantes acerca de los beneficios de cada componente del enfoque multimodal.', 'La primera, ¿cuál es el régimen óptimo para la radioterapia neoadyuvante, el ciclo corto o el ciclo largo?', 'En Polonia, Bujkio y colaboradores compararon el ciclo corto preoperatorio de radioterapia, seguido de cirugía en los siete días siguientes con un ciclo largo de radioquimioterapia, seguido de cirugía en cuatro a seis semanas.', 'La supervivencia global, la supervivencia sin enfermedad y la recurrencia local a los cuatro años fueron similares entre los dos grupos.', 'Sin embargo, los pacientes que recibieron el tratamiento de larga duración presentaron una respuesta patológica completa superior, del 16% frente al 0,7%.', 'Además, el Trans-Tasman Radiation Oncology Group comparó la radioterapia preoperatoria de corta duración y la radioquimioterapia de larga duración en pacientes con tumores T3.', 'No se notificaron diferencias significativas en los resultados oncológicos, pero los pacientes con un ciclo corto de radioterapia presentaron una tasa mayor de recidiva local, con un 7% frente al 4%, y una tasa menor de respuesta patológica completa, con un 1% frente al 15%.', 'En este punto, surge una pregunta más.', '¿Cuál es el pronóstico en lugar de la respuesta patológica completa?', 'En un metanálisis se identificaron 27 artículos basados en 17 conjuntos de datos diferentes de resultados a largo plazo en pacientes con y sin respuesta patológica completa.', 'El criterio principal de valoración fue la supervivencia sin enfermedad a los cinco años, y fue del 83% para los pacientes con respuesta patológica completa frente al 65% para los pacientes sin respuesta patológica completa.', 'Además, tienen mejores resultados a largo plazo, como la recurrencia locorregional, la recurrencia a distancia, y la supervivencia global.', 'Podría ser indicativo de que la respuesta patológica completa es un pronóstico de factor favorable en el cáncer rectal localizado avanzado.', '¿Pero qué pasa si retrasamos la cirugía?', 'En el ensayo de ausencia de inferioridad Stockholm III se investigó la posología óptima y el tiempo hasta la cirugía.', '840 pacientes con cáncer rectal resecable se dividieron en tres grupos.', 'Ciclo corto de radioquimioterapia con cirugía inmediata, ciclo corto de radioquimioterapia con cirugía de cuatro a seis semanas después y ciclo largo de radioquimioterapia.', 'Este resultado no interfirió entre los dos grupos, sin embargo, los pacientes sometidos a un ciclo corto de radioterapia con  ...
# ['Hello, everyone.', "My name is Ramon de Mello and I'm very glad here to coordinate this multidisciplinary session on rectal cancer.", 'Today, we have here experts throughout the world that will discuss multidisciplinary, how can we better approach rectal cancer in order to improve the outcomes?', 'And we have two experts that will give their presentation, a Medical Oncologist, Dr Katia Perez, and Radiation Oncologist, Professor Maria Antonietta Gambacorta.', "So, we'll start with Dr Katia Perez, that will give a view of the Medical Oncologist in rectal cancer and after, we will end-up with Professor Gambacorta, that will give a view of the Radiation Oncologist in rectal cancer treatment.", 'And in the end, we are open to questions and to discuss what you think is pertinent for this section.', 'Katia, please, go ahead.', "Good afternoon, and it's a pleasure to be here today.", "And my name is Katia Roque Perez, and I'm going to present a review of multidisciplinary management on rectal cancer.", 'Before 2020, there are two different standard treatments for locally advanced rectal cancer, a short-course of radiotherapy or long- course of chemo-radiotherapy, followed by TME surgery and adjuvant chemotherapy for patients with risk factors.', "While this multi-modal approach has improved the rates of local recurrence, it hasn't had significant effects on the rates of distant recurrence or overall survival.", 'That is how important questions emerge about the benefits of each component of the multimodal approach.', 'The first one, what is the optimal regimen for neoadjuvant radiotherapy, the short-course or the long-course?', 'In Poland, Bujkio et al. compared pre- operatively short-course of radiotherapy, followed by surgery within seven days. With long-course of chemo- radiotherapy, followed by surgery in four to six weeks.', 'The overall survival, disease-free survival, and local recurrence at four years were similar between the two groups.', 'However, patients who received the long- course had higher pathologic complete response, with 16% versus 0.7%.', 'Also, the Trans-Tasman Radiation Oncology Group compared preoperatively short-course of radiotherapy and long-course of chemo- radiotherapy in patients with T3 tumours.', 'No significant difference in oncology outcomes were reported, but patients with short-course of radiotherapy had a higher rate of local recurrence with 7% versus 4%, and lower rate of pathologic complete response, with 1% versus 15%.', 'At this point, we have one more question.', 'What is the prognosis by lieu of pathologic complete response?', 'A meta-analysis identified 27 articles based on 17 different data sets for long-term outcomes of patients with and without pathologic complete response.', 'Primary outcome was five-year disease-free survival, and it was 83% for patients with pathologic complete response versus 65% for patients without pathologic complete response.', 'Also, they have better long-term outcome, like locoregional recurrence, distant recurrence, and overall survival.', 'It might be indicative of pathologic complete response a prognosis of favourable factor in local advanced rectal cancer.', 'But what happens if we delay surgery?', 'Optimal dosing and time to surgery were investigated in the Stockholm III non- inferiority trial.', '840 patients with resectable rectal cancer were divided in three groups.', 'Short-course of chemo-radiotherapy with immediate surgery, short-course of chemo-radiotherapy with surgery four to six weeks later, and long-course of chemo-radiotherapy.', "This outcome didn't interfere between the two groups, but patients who underwent short-course of radiotherapy with delayed surgery, had a lower rate of post- operative complications, greater tumour regression, and a higher rate of pathologic complete percent, with 11% versus 1%, than patients with immediate surgery.", 'Therefore, short-course of radiotherapy with delayed surgery is a viable alternative to long-course  ...
# Audios: 100%|██████████| 5/5 [30:37<00:00, 367.41s/it]
# ['La diapositiva se centra en la importancia de la atención multidisciplinaria en el tratamiento de la cáncer de mama en mujeres jóvenes.', 'La diapositiva se centra en la importancia de la atención multidisciplinaria en el tratamiento de la cáncer de mama en mujeres jóvenes.', 'Soy oncólogo médico en Dana-Farber, donde me especializo en cáncer de mama en mujeres jóvenes en particular.', 'La importancia de la atención multidisciplinaria en el tratamiento de la cáncer de mama en mujeres jóvenes.', 'La diapositiva se centra en la importancia de la atención multidisciplinaria en el tratamiento de la cáncer de mama en mujeres jóvenes.', 'La diapositiva se centra en la importancia de la evaluación de la enfermedad de la mama en mujeres jóvenes, con un enfoque en los principios de la Comisión Forrester de 1987 para la detección de cáncer de mama.', 'La diapositiva se centra en la importancia de la evaluación de la enfermedad de la mama en mujeres jóvenes, con un enfoque en los principios de la Comisión Forrester de 1987 para la detección de cáncer de mama.', 'Las mujeres jóvenes deben ser evaluadas para la enfermedad de la mama, siguiendo los principios de la Comisión Forrester de 1987.', 'Y concluyeron que la evaluación de las anomalías detectadas por la pantalla requiere técnicas especializadas.', 'Y estas técnicas son mejor realizadas por un equipo multidisciplinario de profesionales capacitados.', 'Este equipo debe estar compuesto por un médico clínico, un radiólogo y un patólogo, todos capacitados en el diagnóstico de la enfermedad de la mama, con el apoyo de un radiógrafo, una enfermera y un recepcionista.', 'La disponibilidad de tales equipos es un requisito esencial para un servicio de detección de cáncer de mama.', 'La diapositiva se centra en la importancia de la evaluación de la enfermedad de la mama en mujeres jóvenes, con un enfoque en los principios de la Comisión Forrester de 1987 para la detección de cáncer de mama.', 'Y posteriormente, a lo largo de muchos años, muchas naciones han adoptado un enfoque multidisciplinario para el cuidado de los pacientes.', 'En los Estados Unidos, donde practico, muchos hospitales comenzaron a hacer lo que se llamaba paneles de oncología.', 'Y este es donde grupos de expertos se reúnen y revisan casos de pacientes, asignan diagnósticos y luego deciden juntos programas de atención para ofrecer a los pacientes.', 'La diapositiva trata sobre la atención médica para mujeres jóvenes con cáncer de mama, enfocándose en la importancia de un enfoque multidisciplinario en el tratamiento.', 'A veces, representantes de los pacientes asisten a estas juntas formales de tumores.', 'Y luego, raramente, los pacientes mismos son invitados a las juntas de oncología.', 'Aunque esto es menos frecuente y especialmente en donde las preocupaciones de privacidad surgen, no se desea que un paciente esté en la sala cuando se habla de otros pacientes.', 'La diapositiva trata sobre la atención médica para mujeres jóvenes con cáncer de mama, enfocándose en la importancia de un enfoque multidisciplinario en el tratamiento.', 'Los Centros Multidisciplinarios de Cáncer de Mama (MDBC) en el Henry Ford Hospital ofrecen un enfoque de "one-stop shopping" para el asesoramiento y apoyo a los pacientes recién diagnosticados.', 'El Centro Multidisciplinario de Cáncer de Mama (MDBC) en el Henry Ford Hospital, Detroit, ofrece un enfoque de "one-stop shopping" para el asesoramiento y apoyo a los pacientes recién diagnosticados. Se comparó el tiempo de inicio del tratamiento y la satisfacción del paciente entre los pacientes que visitaron el MDBC y los que visitaron el hospital de manera tradicional. Se encontró que el MDBC aumentó la satisfacción del paciente y redujo el tiempo entre la diagnóstico y el inicio del tratamiento.', 'La diapositiva discute la efectividad de los Centros Multidisciplinarios de Cáncer de Mama (MDBC) en el Henry Ford Hospital, Detroit, en el tratamiento de pacientes con cáncer de mama.', 'Los Centros M ...
# ['Bien, voy a hablar de la importancia de la atención multidisciplinaria.', 'Como ya han oído, me llamo Ann Partridge.', 'Soy oncóloga médica en el Dana-Farber, donde me centro en el cáncer de mama en mujeres jóvenes en particular.', 'Y no puedo resaltar lo suficiente la importancia de la atención multidisciplinaria para todas las pacientes con cáncer de mama, pero en especial para las pacientes jóvenes.', 'Les daré un ejemplo del por qué, desde mi propia práctica, y me extenderé un poco sobre la historia y lo que implica.', 'Sabemos desde hace décadas que la atención multidisciplinaria marca una diferencia.', 'A finales de los 80, el gobierno del Reino Unido encargó un informe, el informe Forrest, que proponía nuevos principios de cribado del cáncer de mama.', 'Entre estos principios se encuentran que las pacientes con alto índice clínico de sospecha de diagnóstico de cáncer debían someterse a la triple evaluación, que incluye una exploración clínica, la revisión radiológica de las imágenes, y una vez realizada la biopsia, el análisis histopatológico de muestras de tejido.', 'Y concluyeron que la evaluación de las anomalías detectadas en el cribado requería técnicas especializadas.', 'Y estas técnicas las realiza mejor un equipo multidisciplinario experto.', 'Este equipo debe estar formado por un médico, un radiólogo y un patólogo, todos entrenados en el diagnóstico de la enfermedad mamaria, con el apoyo de un radiólogo, una enfermera y un recepcionista.', 'La disponibilidad de estos equipos es un requisito previo esencial de un servicio de cribado del cáncer de mama.', 'Así que ese fue algo así como el comienzo del reconocimiento formal de la importancia de los diferentes papeles que, diferentes individuos, con diferentes conocimientos, podrían desempeñar para una persona con un diagnóstico de cáncer de mama.', 'Y, posteriormente, a lo largo de las décadas, muchos países han adoptado un enfoque multidisciplinario en cuanto a la atención, en diversas formas y modos.', 'En EE. UU., donde ejerzo, muchos hospitales comenzaron a hacer lo que se llamó comités de tumores.', 'Y es aquí donde grupos de expertos se reúnen y revisan casos de pacientes, asignan diagnósticos, y luego deciden juntos programas de atención que ofrecer al paciente.', 'Por supuesto, el enfoque varía de un centro a otro, pero muchos incluyen a menudo la participación de un médico a nivel asistencial, un cirujano, un patólogo, un radiólogo y un oncólogo, con participación variable de especialistas, enfermeros, profesionales relacionados con la salud, y vamos a entrar en algunos ejemplos que son especialmente pertinentes para las mujeres jóvenes.', 'A veces los representantes de los pacientes están en estos comités de tumores formales.', 'Y, luego, en raras ocasiones, los propios pacientes son invitados a los comités de tumores.', 'Aunque esto es menos frecuente, y especialmente cuando surgen problemas de privacidad, no quieres a un paciente en la sala cuando estamos hablando de otros pacientes.', 'Eso puede volverse bastante complicado, tanto desde el punto de vista de la confidencialidad, como también desde el punto de vista logístico, para muchas de estas cosas.', '¿Cómo suelen funcionar y, funcionan?', 'Bueno, hay datos que se han ido obteniendo con los años que sugieren que realmente funcionan.', 'Este es uno de los primeros estudios que se realizó en Michigan, Estados Unidos.', 'Y la pregunta que hicieron fue: «Clínicas multidisciplinarias de cáncer de mama.', '¿Funcionan?»', 'Esto se llevó a cabo en el Henry Ford Hospital en Detroit, y ellos mismos desarrollaron, como hacían muchos en ese momento, en los 90, una clínica multidisciplinaria de cáncer de mama, la MDBCC, para ofrecer una «ventanilla única», consultas y apoyo para pacientes recién diagnosticadas de cáncer de mama.', 'Y aplicaron un enfoque de control histórico.', 'Así que compararon a las primeras 177 pacientes, atendidas en su nueva clínica multidisciplinaria, con 162 controles que habían sid ...
# ["So, I'm gonna talk about the importance of multidisciplinary care.", 'As you heard, my name is Ann Partridge.', "I'm a medical oncologist at Dana-Farber, where I focus on breast cancer in young women, in particular.", "And I can't emphasize enough the importance of multidisciplinary care for all patients with breast cancer, but particularly for young patients.", "And I'll give you an example of why, from my own practice, as well as discuss a little bit of the history and what it entails.", "We've known for decades that multidisciplinary care makes a difference.", 'Back in late 80s, the UK government actually commissioned a report, The Forrest Report, which proposed new principles of screening for breast cancer.', 'Among these principles were the patients with a high clinical index of suspicion for a cancer diagnosis, should receive the triple-assessment, and that included a clinical exam, radiologic review of images, and once a biopsy is done, histopathological analysis of tissue samples.', 'And they concluded that the assessment of screen detected abnormalities requires specialized techniques.', 'And these techniques are best carried out by a skilled multidisciplinary team.', 'This team should consist of a clinician, a radiologist, and a pathologist, all trained in the diagnosis of breast disease, supported by a radiographer, a nurse, and receptionist.', 'The availability of such teams is an essential prerequisite of a screening service for breast cancer.', 'So, that was kind of the beginning of the formal recognition of the importance of the different parts that, different individuals, with different expertise, might play for an individual with a diagnosis of breast cancer.', 'And, subsequently, over the many decades, many nations have adopted a multidisciplinary approach to care in various shapes and forms.', 'In the US, where I practice, many hospitals started doing what was called tumor boards.', 'And this is where groups of experts meet and review patient cases, assign diagnoses, and then decide together programs of care to offer to the patient.', "Of course, the approach varies from center to center, but many include an attending level physician, a surgeon, pathologist, radiologist and oncologist are often involved, with variable involvement of specialists, nurses, allied health professionals, and we'll get into some examples that are particularly pertinent for young women.", 'Sometimes patient representatives are at these formal tumor boards.', 'And, then, rarely, patients themselves are invited to the tumor boards.', "Although, this is less frequent, and especially where privacy concerns come up, you don't want a patient in the room when we're talking about other patients.", 'So. that can become quite tricky, both from a confidentiality standpoint, and also from a logistics standpoint, for many of these things.', 'How do they typically work, and do they work?', 'Well, there were data that have evolved over the years that suggest that they do indeed work.', 'This is one of the first studies that was conducted in Michigan in the United States.', 'And the question they asked was, " Multidisciplinary breast cancer clinics.', 'Do they work?"', 'This was conducted at the Henry Ford Hospital in Detroit, and they developed themselves, like many at the time were doing, in the 90s, a multidisciplinary breast clinic, the MDBCC, to offer one-stop- shopping, consultation and support for newly diagnosed breast cancer patients.', 'And they did a historical control approach.', "So, they compared the first 177 patients, seen in their new multidisciplinary clinic, to 162 controls who had been seen in the year before in the traditional sequential manner, where a patient would go and see the surgeon, and then maybe after the surgery, unless the surgeon thought they might need preoperative therapy, they'd send them to the medical oncologist, and the radiation oncologist, as treatment has evolved.", 'And there may or may not be a nurse i ...

# %%
global_metrics, per_audio = bleu_comet_by_audio(refs, hyps, srcs,
                                                comet_gpus=1, comet_batch_size=8)
# Out:
# Fetching 5 files:   0%|          | 0/5 [00:00<?, ?it/s]
# hparams.yaml:   0%|          | 0.00/567 [00:00<?, ?B/s]
# LICENSE: 0.00B [00:00, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# .gitattributes: 0.00B [00:00, ?B/s]
# checkpoints/model.ckpt:   0%|          | 0.00/2.32G [00:00<?, ?B/s]
# INFO:pytorch_lightning.utilities.migration.utils:Lightning automatically upgraded your loaded checkpoint from v1.8.3.post1 to v2.5.3. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint ../root/.cache/huggingface/hub/models--Unbabel--wmt22-comet-da/snapshots/2760a223ac957f30acfb18c8aa649b01cf1d75f2/checkpoints/model.ckpt`
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.10M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/616 [00:00<?, ?B/s]
# /usr/local/lib/python3.12/dist-packages/pytorch_lightning/core/saving.py:195: Found keys that are not in the model state dict but in the checkpoint: ['encoder.model.embeddings.position_ids']
# INFO:pytorch_lightning.utilities.rank_zero:💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.utilities.rank_zero:You are using a CUDA device ('NVIDIA A100-SXM4-40GB') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.utilities.rank_zero:💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]

# %%
print("BLEU  global :", global_metrics["bleu"])
print("COMET-22    :", global_metrics["comet22"])
# Out:
# BLEU  global : 20.8754686449739
# COMET-22    : 0.6869584716087559

# %%
per_audio
# Out:
# [{'audio_id': 0, 'bleu': 18.224811543811374, 'comet22': 0.6792517582331699},
#  {'audio_id': 1, 'bleu': 23.15338352052172, 'comet22': 0.711343354916986},
#  {'audio_id': 2, 'bleu': 18.43010238218834, 'comet22': 0.6701103697426586},
#  {'audio_id': 3, 'bleu': 18.370959080317302, 'comet22': 0.7034558144847999},
#  {'audio_id': 4, 'bleu': 17.31098294999179, 'comet22': 0.6633871623447963}]
